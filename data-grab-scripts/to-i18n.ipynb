# %% [markdown]
# # Convert Card Data to i18n Format
#
# This notebook converts the structured card data to a format suitable for i18n in a Nuxt.js project, with English field names as keys.

# %%
import json
import re
from pathlib import Path

# %%
# Define mapping of Japanese field names to English field names
field_mapping = {
    # Card basic info
    'カードタイプ': 'cardType',
    'タグ': 'tags',
    'レアリティ': 'rarity',
    '収録商品': 'set',
    'カードナンバー': 'cardNumber',
    'イラストレーター': 'illustrator',
    
    # Card attributes
    '色': 'color',
    'HP': 'hp',
    'LIFE': 'life',
    'Bloomレベル': 'bloomLevel',
    'バトンタッチ': 'batonTouch',
    
    # Card abilities
    'アーツ': 'arts',
    'エクストラ': 'extra',
    'キーワード': 'keyword',
    '推しスキル': 'oshiSkill',
    'SP推しスキル': 'spOshiSkill',
    '能力テキスト': 'abilityText',
    
    # Arts and skill components
    'name': 'name',
    'effect': 'effect',
    'full_text': 'fullText',
    'damage': 'damage',
    'cost': 'cost',
    'timing': 'timing',
    'count': 'count',
    'images': 'images',
    'cost_icons': 'costIcons',
    'tokkou': 'special',
    'icon': 'icon',
    'value': 'value'
}

# Define bloom level mapping
bloom_level_mapping = {
    'Debut': 'debut',
    '1st': 'first',
    '2nd': 'second'
}

# Define color mapping
color_mapping = {
    '白': 'white',
    '赤': 'red',
    '青': 'blue',
    '緑': 'green',
    '黄': 'yellow',
    '紫': 'purple'
}

# Card type mapping
card_type_mapping = {
    'ホロメン': 'character',
    'Buzzホロメン': 'buzzCharacter',
    '推しホロメン': 'oshiCharacter',
    'サポート・イベント': 'supportEvent',
    'サポート・イベント・LIMITED': 'supportEventLimited',
    'サポート・アイテム': 'supportItem',
    'サポート・ファン': 'supportFan',
    'サポート・ツール': 'supportTool',
    'サポート・ロケーション': 'supportLocation',
    'サポート・エール': 'supportCheer'
}

# %%
def convert_card_to_i18n(card, default_language='ja'):
    """Convert a card's structured data to i18n format with English keys."""
    i18n_card = {
        'id': card.get('id', ''),
        'translations': {}
    }
    
    # Initialize translations for the default language
    translations = {}
    
    # Process card number and image paths if available
    if 'カードナンバー' in card:
        i18n_card['cardNumber'] = card['カードナンバー']
        
    if 'image_path' in card:
        i18n_card['imagePath'] = card['image_path']
    
    if 'image_url' in card:
        i18n_card['imageUrl'] = card['image_url']
        
    # Process name separately as it's often at the top level
    if 'name' in card:
        translations['name'] = card['name']
    
    # Process card type
    if 'カードタイプ' in card:
        card_type_ja = card['カードタイプ']
        translations['cardType'] = card_type_ja
        i18n_card['cardTypeCode'] = card_type_mapping.get(card_type_ja, 'unknown')
    
    # Process card color
    if '色' in card:
        if isinstance(card['色'], dict) and 'value' in card['色']:
            color_ja = card['色']['value']
            translations['color'] = color_ja
            i18n_card['colorCode'] = color_mapping.get(color_ja, 'unknown')
        elif isinstance(card['色'], str):
            color_ja = card['色']
            translations['color'] = color_ja
            i18n_card['colorCode'] = color_mapping.get(color_ja, 'unknown')
    
    # Process bloom level
    if 'Bloomレベル' in card:
        bloom_level_ja = card['Bloomレベル']
        translations['bloomLevel'] = bloom_level_ja
        i18n_card['bloomLevelCode'] = bloom_level_mapping.get(bloom_level_ja, 'unknown')
    
    # Process numeric values directly
    for jp_field, en_field in [
        ('HP', 'hp'), 
        ('LIFE', 'life')
    ]:
        if jp_field in card:
            try:
                i18n_card[en_field] = int(card[jp_field])
            except (ValueError, TypeError):
                i18n_card[en_field] = card[jp_field]
    
    # Process tags
    if 'タグ' in card and isinstance(card['タグ'], list):
        tags = []
        tag_translations = []
        
        for tag in card['タグ']:
            if isinstance(tag, dict) and 'name' in tag:
                tag_name = tag['name']
                tag_code = tag_name.replace('#', '')
                tags.append(tag_code)
                tag_translations.append(tag_name)
            elif isinstance(tag, str):
                tag_code = tag.replace('#', '')
                tags.append(tag_code)
                tag_translations.append(tag)
        
        i18n_card['tags'] = tags
        translations['tags'] = tag_translations
    
    # Process rarity
    if 'レアリティ' in card:
        translations['rarity'] = card['レアリティ']
        i18n_card['rarityCode'] = card['レアリティ']
    
    # Process set
    if '収録商品' in card:
        translations['set'] = card['収録商品']
    
    # Process illustrator
    if 'イラストレーター' in card:
        translations['illustrator'] = card['イラストレーター']
    
    # Process ability text for support cards
    if '能力テキスト' in card:
        translations['abilityText'] = card['能力テキスト']
    
    # Process extra text
    if 'エクストラ' in card:
        translations['extra'] = card['エクストラ']
    
    # Process baton touch
    if 'バトンタッチ' in card:
        if isinstance(card['バトンタッチ'], dict) and 'count' in card['バトンタッチ']:
            i18n_card['batonTouchCount'] = card['バトンタッチ']['count']
    
    # Process arts
    if 'アーツ' in card and isinstance(card['アーツ'], list):
        arts_list = []
        arts_translations = []
        
        for i, arts in enumerate(card['アーツ']):
            arts_data = {}
            arts_translation = {}
            
            # Handle cost icons
            if 'cost_icons' in arts and isinstance(arts['cost_icons'], list):
                cost_count = len(arts['cost_icons'])
                arts_data['costCount'] = cost_count
                
                # Extract cost types based on alt text
                cost_types = []
                for icon in arts['cost_icons']:
                    if isinstance(icon, dict) and 'alt' in icon:
                        alt = icon['alt']
                        if alt in color_mapping:
                            cost_types.append(color_mapping[alt])
                        elif alt == '◇':
                            cost_types.append('neutral')
                arts_data['costTypes'] = cost_types
            
            # Handle arts name
            if 'name' in arts:
                arts_translation['name'] = arts['name']
            
            # Handle damage value
            if 'damage' in arts:
                try:
                    # Extract base damage without '+' if present
                    damage_str = arts['damage']
                    base_damage = re.match(r'(\d+)', damage_str)
                    if base_damage:
                        arts_data['damage'] = int(base_damage.group(1))
                    
                    # Check if it's a plus damage
                    if '+' in damage_str:
                        arts_data['isPlus'] = True
                except (ValueError, TypeError):
                    arts_data['damage'] = arts['damage']
            
            # Handle special damage
            if 'tokkou' in arts and isinstance(arts['tokkou'], list):
                special_targets = []
                special_values = []
                
                for special in arts['tokkou']:
                    if isinstance(special, dict) and 'alt' in special:
                        alt_text = special['alt']
                        # Parse special damage like "赤+50"
                        match = re.match(r'([^+]+)\+(\d+)', alt_text)
                        if match:
                            color_name = match.group(1)
                            damage_value = int(match.group(2))
                            if color_name in color_mapping:
                                target = color_mapping[color_name]
                                special_targets.append(target)
                                special_values.append(damage_value)
                
                if special_targets:
                    arts_data['specialTargets'] = special_targets
                    arts_data['specialValues'] = special_values
            
            # Handle effect text
            if 'effect' in arts:
                arts_translation['effect'] = arts['effect']
                
            # Add to lists
            arts_list.append(arts_data)
            arts_translations.append(arts_translation)
        
        i18n_card['arts'] = arts_list
        translations['arts'] = arts_translations
    
    # Process keyword abilities
    if 'キーワード' in card and isinstance(card['キーワード'], dict):
        keyword = card['キーワード']
        keyword_data = {}
        keyword_translation = {}
        
        # Extract keyword type from icon
        if 'icon' in keyword and isinstance(keyword['icon'], dict) and 'alt' in keyword['icon']:
            keyword_type = keyword['icon']['alt']
            keyword_data['type'] = keyword_type
            
            # Map keyword types to codes
            keyword_type_code = keyword_type.lower()
            if 'コラボエフェクト' in keyword_type:
                keyword_type_code = 'collab_effect'
            elif 'ブルームエフェクト' in keyword_type:
                keyword_type_code = 'bloom_effect'
            elif 'ギフト' in keyword_type:
                keyword_type_code = 'gift'
            
            keyword_data['typeCode'] = keyword_type_code
        
        # Extract name and effect
        if 'name' in keyword:
            keyword_translation['name'] = keyword['name']
        
        if 'effect' in keyword:
            keyword_translation['effect'] = keyword['effect']
        
        i18n_card['keyword'] = keyword_data
        translations['keyword'] = keyword_translation
    
    # Process oshi skill
    for skill_type, en_field in [('推しスキル', 'oshiSkill'), ('SP推しスキル', 'spOshiSkill')]:
        if skill_type in card and isinstance(card[skill_type], dict):
            skill = card[skill_type]
            skill_data = {}
            skill_translation = {}
            
            # Extract cost
            if 'cost' in skill:
                try:
                    # Cost is usually a negative number like "-2"
                    skill_data['cost'] = int(skill['cost'])
                except (ValueError, TypeError):
                    skill_data['cost'] = skill['cost']
            
            # Extract timing
            if 'timing' in skill:
                timing_text = skill['timing']
                skill_translation['timing'] = timing_text
                
                # Map timing to code
                timing_code = 'unknown'
                if 'ターンに1回' in timing_text:
                    timing_code = 'once_per_turn'
                elif 'ゲームに1回' in timing_text:
                    timing_code = 'once_per_game'
                
                skill_data['timingCode'] = timing_code
            
            # Extract name and effect
            if 'name' in skill:
                skill_translation['name'] = skill['name']
            
            if 'effect' in skill:
                skill_translation['effect'] = skill['effect']
            
            i18n_card[en_field] = skill_data
            translations[en_field] = skill_translation
    
    # Add translations to the card
    i18n_card['translations'][default_language] = translations
    
    return i18n_card

# %%
def generate_card_i18n_data(input_file='./cards_structured.json', output_file='./cards_i18n.json'):
    """Process all structured card data and convert to i18n format."""
    # Load structured data
    try:
        with open(input_file, 'r', encoding='utf-8') as f:
            cards_data = json.load(f)
    except FileNotFoundError:
        print(f"Error: Input file '{input_file}' not found.")
        return
    except json.JSONDecodeError:
        print(f"Error: Input file '{input_file}' contains invalid JSON.")
        return
    
    # Convert each card to i18n format
    i18n_cards = []
    for i, card in enumerate(cards_data):
        print(f"Processing card {i+1}/{len(cards_data)}")
        i18n_card = convert_card_to_i18n(card)
        i18n_cards.append(i18n_card)
    
    # Save the result
    try:
        with open(output_file, 'w', encoding='utf-8') as f:
            json.dump(i18n_cards, f, ensure_ascii=False, indent=2)
        print(f"Success: Converted {len(i18n_cards)} cards to i18n format. Saved to '{output_file}'.")
    except Exception as e:
        print(f"Error saving output file: {str(e)}")
    
    return i18n_cards

# %%
# Generate card i18n data
i18n_cards = generate_card_i18n_data()
# Out:
# Processing card 1/845
# Processing card 2/845
# Processing card 3/845
# Processing card 4/845
# Processing card 5/845
# Processing card 6/845
# Processing card 7/845
# Processing card 8/845
# Processing card 9/845
# Processing card 10/845
# Processing card 11/845
# Processing card 12/845
# Processing card 13/845
# Processing card 14/845
# Processing card 15/845
# Processing card 16/845
# Processing card 17/845
# Processing card 18/845
# Processing card 19/845
# Processing card 20/845
# Processing card 21/845
# Processing card 22/845
# Processing card 23/845
# Processing card 24/845
# Processing card 25/845
# Processing card 26/845
# Processing card 27/845
# Processing card 28/845
# Processing card 29/845
# Processing card 30/845
# Processing card 31/845
# Processing card 32/845
# Processing card 33/845
# Processing card 34/845
# Processing card 35/845
# Processing card 36/845
# Processing card 37/845
# Processing card 38/845
# Processing card 39/845
# Processing card 40/845
# Processing card 41/845
# Processing card 42/845
# Processing card 43/845
# Processing card 44/845
# Processing card 45/845
# Processing card 46/845
# Processing card 47/845
# Processing card 48/845
# Processing card 49/845
# Processing card 50/845
# Processing card 51/845
# Processing card 52/845
# Processing card 53/845
# Processing card 54/845
# Processing card 55/845
# Processing card 56/845
# Processing card 57/845
# Processing card 58/845
# Processing card 59/845
# Processing card 60/845
# Processing card 61/845
# Processing card 62/845
# Processing card 63/845
# Processing card 64/845
# Processing card 65/845
# Processing card 66/845
# Processing card 67/845
# Processing card 68/845
# Processing card 69/845
# Processing card 70/845
# Processing card 71/845
# Processing card 72/845
# Processing card 73/845
# Processing card 74/845
# Processing card 75/845
# Processing card 76/845
# Processing card 77/845
# Processing card 78/845
# Processing card 79/845
# Processing card 80/845
# Processing card 81/845
# Processing card 82/845
# Processing card 83/845
# Processing card 84/845
# Processing card 85/845
# Processing card 86/845
# Processing card 87/845
# Processing card 88/845
# Processing card 89/845
# Processing card 90/845
# Processing card 91/845
# Processing card 92/845
# Processing card 93/845
# Processing card 94/845
# Processing card 95/845
# Processing card 96/845
# Processing card 97/845
# Processing card 98/845
# Processing card 99/845
# Processing card 100/845
# Processing card 101/845
# Processing card 102/845
# Processing card 103/845
# Processing card 104/845
# Processing card 105/845
# Processing card 106/845
# Processing card 107/845
# Processing card 108/845
# Processing card 109/845
# Processing card 110/845
# Processing card 111/845
# Processing card 112/845
# Processing card 113/845
# Processing card 114/845
# Processing card 115/845
# Processing card 116/845
# Processing card 117/845
# Processing card 118/845
# Processing card 119/845
# Processing card 120/845
# Processing card 121/845
# Processing card 122/845
# Processing card 123/845
# Processing card 124/845
# Processing card 125/845
# Processing card 126/845
# Processing card 127/845
# Processing card 128/845
# Processing card 129/845
# Processing card 130/845
# Processing card 131/845
# Processing card 132/845
# Processing card 133/845
# Processing card 134/845
# Processing card 135/845
# Processing card 136/845
# Processing card 137/845
# Processing card 138/845
# Processing card 139/845
# Processing card 140/845
# Processing card 141/845
# Processing card 142/845
# Processing card 143/845
# Processing card 144/845
# Processing card 145/845
# Processing card 146/845
# Processing card 147/845
# Processing card 148/845
# Processing card 149/845
# Processing card 150/845
# Processing card 151/845
# Processing card 152/845
# Processing card 153/845
# Processing card 154/845
# Processing card 155/845
# Processing card 156/845
# Processing card 157/845
# Processing card 158/845
# Processing card 159/845
# Processing card 160/845
# Processing card 161/845
# Processing card 162/845
# Processing card 163/845
# Processing card 164/845
# Processing card 165/845
# Processing card 166/845
# Processing card 167/845
# Processing card 168/845
# Processing card 169/845
# Processing card 170/845
# Processing card 171/845
# Processing card 172/845
# Processing card 173/845
# Processing card 174/845
# Processing card 175/845
# Processing card 176/845
# Processing card 177/845
# Processing card 178/845
# Processing card 179/845
# Processing card 180/845
# Processing card 181/845
# Processing card 182/845
# Processing card 183/845
# Processing card 184/845
# Processing card 185/845
# Processing card 186/845
# Processing card 187/845
# Processing card 188/845
# Processing card 189/845
# Processing card 190/845
# Processing card 191/845
# Processing card 192/845
# Processing card 193/845
# Processing card 194/845
# Processing card 195/845
# Processing card 196/845
# Processing card 197/845
# Processing card 198/845
# Processing card 199/845
# Processing card 200/845
# Processing card 201/845
# Processing card 202/845
# Processing card 203/845
# Processing card 204/845
# Processing card 205/845
# Processing card 206/845
# Processing card 207/845
# Processing card 208/845
# Processing card 209/845
# Processing card 210/845
# Processing card 211/845
# Processing card 212/845
# Processing card 213/845
# Processing card 214/845
# Processing card 215/845
# Processing card 216/845
# Processing card 217/845
# Processing card 218/845
# Processing card 219/845
# Processing card 220/845
# Processing card 221/845
# Processing card 222/845
# Processing card 223/845
# Processing card 224/845
# Processing card 225/845
# Processing card 226/845
# Processing card 227/845
# Processing card 228/845
# Processing card 229/845
# Processing card 230/845
# Processing card 231/845
# Processing card 232/845
# Processing card 233/845
# Processing card 234/845
# Processing card 235/845
# Processing card 236/845
# Processing card 237/845
# Processing card 238/845
# Processing card 239/845
# Processing card 240/845
# Processing card 241/845
# Processing card 242/845
# Processing card 243/845
# Processing card 244/845
# Processing card 245/845
# Processing card 246/845
# Processing card 247/845
# Processing card 248/845
# Processing card 249/845
# Processing card 250/845
# Processing card 251/845
# Processing card 252/845
# Processing card 253/845
# Processing card 254/845
# Processing card 255/845
# Processing card 256/845
# Processing card 257/845
# Processing card 258/845
# Processing card 259/845
# Processing card 260/845
# Processing card 261/845
# Processing card 262/845
# Processing card 263/845
# Processing card 264/845
# Processing card 265/845
# Processing card 266/845
# Processing card 267/845
# Processing card 268/845
# Processing card 269/845
# Processing card 270/845
# Processing card 271/845
# Processing card 272/845
# Processing card 273/845
# Processing card 274/845
# Processing card 275/845
# Processing card 276/845
# Processing card 277/845
# Processing card 278/845
# Processing card 279/845
# Processing card 280/845
# Processing card 281/845
# Processing card 282/845
# Processing card 283/845
# Processing card 284/845
# Processing card 285/845
# Processing card 286/845
# Processing card 287/845
# Processing card 288/845
# Processing card 289/845
# Processing card 290/845
# Processing card 291/845
# Processing card 292/845
# Processing card 293/845
# Processing card 294/845
# Processing card 295/845
# Processing card 296/845
# Processing card 297/845
# Processing card 298/845
# Processing card 299/845
# Processing card 300/845
# Processing card 301/845
# Processing card 302/845
# Processing card 303/845
# Processing card 304/845
# Processing card 305/845
# Processing card 306/845
# Processing card 307/845
# Processing card 308/845
# Processing card 309/845
# Processing card 310/845
# Processing card 311/845
# Processing card 312/845
# Processing card 313/845
# Processing card 314/845
# Processing card 315/845
# Processing card 316/845
# Processing card 317/845
# Processing card 318/845
# Processing card 319/845
# Processing card 320/845
# Processing card 321/845
# Processing card 322/845
# Processing card 323/845
# Processing card 324/845
# Processing card 325/845
# Processing card 326/845
# Processing card 327/845
# Processing card 328/845
# Processing card 329/845
# Processing card 330/845
# Processing card 331/845
# Processing card 332/845
# Processing card 333/845
# Processing card 334/845
# Processing card 335/845
# Processing card 336/845
# Processing card 337/845
# Processing card 338/845
# Processing card 339/845
# Processing card 340/845
# Processing card 341/845
# Processing card 342/845
# Processing card 343/845
# Processing card 344/845
# Processing card 345/845
# Processing card 346/845
# Processing card 347/845
# Processing card 348/845
# Processing card 349/845
# Processing card 350/845
# Processing card 351/845
# Processing card 352/845
# Processing card 353/845
# Processing card 354/845
# Processing card 355/845
# Processing card 356/845
# Processing card 357/845
# Processing card 358/845
# Processing card 359/845
# Processing card 360/845
# Processing card 361/845
# Processing card 362/845
# Processing card 363/845
# Processing card 364/845
# Processing card 365/845
# Processing card 366/845
# Processing card 367/845
# Processing card 368/845
# Processing card 369/845
# Processing card 370/845
# Processing card 371/845
# Processing card 372/845
# Processing card 373/845
# Processing card 374/845
# Processing card 375/845
# Processing card 376/845
# Processing card 377/845
# Processing card 378/845
# Processing card 379/845
# Processing card 380/845
# Processing card 381/845
# Processing card 382/845
# Processing card 383/845
# Processing card 384/845
# Processing card 385/845
# Processing card 386/845
# Processing card 387/845
# Processing card 388/845
# Processing card 389/845
# Processing card 390/845
# Processing card 391/845
# Processing card 392/845
# Processing card 393/845
# Processing card 394/845
# Processing card 395/845
# Processing card 396/845
# Processing card 397/845
# Processing card 398/845
# Processing card 399/845
# Processing card 400/845
# Processing card 401/845
# Processing card 402/845
# Processing card 403/845
# Processing card 404/845
# Processing card 405/845
# Processing card 406/845
# Processing card 407/845
# Processing card 408/845
# Processing card 409/845
# Processing card 410/845
# Processing card 411/845
# Processing card 412/845
# Processing card 413/845
# Processing card 414/845
# Processing card 415/845
# Processing card 416/845
# Processing card 417/845
# Processing card 418/845
# Processing card 419/845
# Processing card 420/845
# Processing card 421/845
# Processing card 422/845
# Processing card 423/845
# Processing card 424/845
# Processing card 425/845
# Processing card 426/845
# Processing card 427/845
# Processing card 428/845
# Processing card 429/845
# Processing card 430/845
# Processing card 431/845
# Processing card 432/845
# Processing card 433/845
# Processing card 434/845
# Processing card 435/845
# Processing card 436/845
# Processing card 437/845
# Processing card 438/845
# Processing card 439/845
# Processing card 440/845
# Processing card 441/845
# Processing card 442/845
# Processing card 443/845
# Processing card 444/845
# Processing card 445/845
# Processing card 446/845
# Processing card 447/845
# Processing card 448/845
# Processing card 449/845
# Processing card 450/845
# Processing card 451/845
# Processing card 452/845
# Processing card 453/845
# Processing card 454/845
# Processing card 455/845
# Processing card 456/845
# Processing card 457/845
# Processing card 458/845
# Processing card 459/845
# Processing card 460/845
# Processing card 461/845
# Processing card 462/845
# Processing card 463/845
# Processing card 464/845
# Processing card 465/845
# Processing card 466/845
# Processing card 467/845
# Processing card 468/845
# Processing card 469/845
# Processing card 470/845
# Processing card 471/845
# Processing card 472/845
# Processing card 473/845
# Processing card 474/845
# Processing card 475/845
# Processing card 476/845
# Processing card 477/845
# Processing card 478/845
# Processing card 479/845
# Processing card 480/845
# Processing card 481/845
# Processing card 482/845
# Processing card 483/845
# Processing card 484/845
# Processing card 485/845
# Processing card 486/845
# Processing card 487/845
# Processing card 488/845
# Processing card 489/845
# Processing card 490/845
# Processing card 491/845
# Processing card 492/845
# Processing card 493/845
# Processing card 494/845
# Processing card 495/845
# Processing card 496/845
# Processing card 497/845
# Processing card 498/845
# Processing card 499/845
# Processing card 500/845
# Processing card 501/845
# Processing card 502/845
# Processing card 503/845
# Processing card 504/845
# Processing card 505/845
# Processing card 506/845
# Processing card 507/845
# Processing card 508/845
# Processing card 509/845
# Processing card 510/845
# Processing card 511/845
# Processing card 512/845
# Processing card 513/845
# Processing card 514/845
# Processing card 515/845
# Processing card 516/845
# Processing card 517/845
# Processing card 518/845
# Processing card 519/845
# Processing card 520/845
# Processing card 521/845
# Processing card 522/845
# Processing card 523/845
# Processing card 524/845
# Processing card 525/845
# Processing card 526/845
# Processing card 527/845
# Processing card 528/845
# Processing card 529/845
# Processing card 530/845
# Processing card 531/845
# Processing card 532/845
# Processing card 533/845
# Processing card 534/845
# Processing card 535/845
# Processing card 536/845
# Processing card 537/845
# Processing card 538/845
# Processing card 539/845
# Processing card 540/845
# Processing card 541/845
# Processing card 542/845
# Processing card 543/845
# Processing card 544/845
# Processing card 545/845
# Processing card 546/845
# Processing card 547/845
# Processing card 548/845
# Processing card 549/845
# Processing card 550/845
# Processing card 551/845
# Processing card 552/845
# Processing card 553/845
# Processing card 554/845
# Processing card 555/845
# Processing card 556/845
# Processing card 557/845
# Processing card 558/845
# Processing card 559/845
# Processing card 560/845
# Processing card 561/845
# Processing card 562/845
# Processing card 563/845
# Processing card 564/845
# Processing card 565/845
# Processing card 566/845
# Processing card 567/845
# Processing card 568/845
# Processing card 569/845
# Processing card 570/845
# Processing card 571/845
# Processing card 572/845
# Processing card 573/845
# Processing card 574/845
# Processing card 575/845
# Processing card 576/845
# Processing card 577/845
# Processing card 578/845
# Processing card 579/845
# Processing card 580/845
# Processing card 581/845
# Processing card 582/845
# Processing card 583/845
# Processing card 584/845
# Processing card 585/845
# Processing card 586/845
# Processing card 587/845
# Processing card 588/845
# Processing card 589/845
# Processing card 590/845
# Processing card 591/845
# Processing card 592/845
# Processing card 593/845
# Processing card 594/845
# Processing card 595/845
# Processing card 596/845
# Processing card 597/845
# Processing card 598/845
# Processing card 599/845
# Processing card 600/845
# Processing card 601/845
# Processing card 602/845
# Processing card 603/845
# Processing card 604/845
# Processing card 605/845
# Processing card 606/845
# Processing card 607/845
# Processing card 608/845
# Processing card 609/845
# Processing card 610/845
# Processing card 611/845
# Processing card 612/845
# Processing card 613/845
# Processing card 614/845
# Processing card 615/845
# Processing card 616/845
# Processing card 617/845
# Processing card 618/845
# Processing card 619/845
# Processing card 620/845
# Processing card 621/845
# Processing card 622/845
# Processing card 623/845
# Processing card 624/845
# Processing card 625/845
# Processing card 626/845
# Processing card 627/845
# Processing card 628/845
# Processing card 629/845
# Processing card 630/845
# Processing card 631/845
# Processing card 632/845
# Processing card 633/845
# Processing card 634/845
# Processing card 635/845
# Processing card 636/845
# Processing card 637/845
# Processing card 638/845
# Processing card 639/845
# Processing card 640/845
# Processing card 641/845
# Processing card 642/845
# Processing card 643/845
# Processing card 644/845
# Processing card 645/845
# Processing card 646/845
# Processing card 647/845
# Processing card 648/845
# Processing card 649/845
# Processing card 650/845
# Processing card 651/845
# Processing card 652/845
# Processing card 653/845
# Processing card 654/845
# Processing card 655/845
# Processing card 656/845
# Processing card 657/845
# Processing card 658/845
# Processing card 659/845
# Processing card 660/845
# Processing card 661/845
# Processing card 662/845
# Processing card 663/845
# Processing card 664/845
# Processing card 665/845
# Processing card 666/845
# Processing card 667/845
# Processing card 668/845
# Processing card 669/845
# Processing card 670/845
# Processing card 671/845
# Processing card 672/845
# Processing card 673/845
# Processing card 674/845
# Processing card 675/845
# Processing card 676/845
# Processing card 677/845
# Processing card 678/845
# Processing card 679/845
# Processing card 680/845
# Processing card 681/845
# Processing card 682/845
# Processing card 683/845
# Processing card 684/845
# Processing card 685/845
# Processing card 686/845
# Processing card 687/845
# Processing card 688/845
# Processing card 689/845
# Processing card 690/845
# Processing card 691/845
# Processing card 692/845
# Processing card 693/845
# Processing card 694/845
# Processing card 695/845
# Processing card 696/845
# Processing card 697/845
# Processing card 698/845
# Processing card 699/845
# Processing card 700/845
# Processing card 701/845
# Processing card 702/845
# Processing card 703/845
# Processing card 704/845
# Processing card 705/845
# Processing card 706/845
# Processing card 707/845
# Processing card 708/845
# Processing card 709/845
# Processing card 710/845
# Processing card 711/845
# Processing card 712/845
# Processing card 713/845
# Processing card 714/845
# Processing card 715/845
# Processing card 716/845
# Processing card 717/845
# Processing card 718/845
# Processing card 719/845
# Processing card 720/845
# Processing card 721/845
# Processing card 722/845
# Processing card 723/845
# Processing card 724/845
# Processing card 725/845
# Processing card 726/845
# Processing card 727/845
# Processing card 728/845
# Processing card 729/845
# Processing card 730/845
# Processing card 731/845
# Processing card 732/845
# Processing card 733/845
# Processing card 734/845
# Processing card 735/845
# Processing card 736/845
# Processing card 737/845
# Processing card 738/845
# Processing card 739/845
# Processing card 740/845
# Processing card 741/845
# Processing card 742/845
# Processing card 743/845
# Processing card 744/845
# Processing card 745/845
# Processing card 746/845
# Processing card 747/845
# Processing card 748/845
# Processing card 749/845
# Processing card 750/845
# Processing card 751/845
# Processing card 752/845
# Processing card 753/845
# Processing card 754/845
# Processing card 755/845
# Processing card 756/845
# Processing card 757/845
# Processing card 758/845
# Processing card 759/845
# Processing card 760/845
# Processing card 761/845
# Processing card 762/845
# Processing card 763/845
# Processing card 764/845
# Processing card 765/845
# Processing card 766/845
# Processing card 767/845
# Processing card 768/845
# Processing card 769/845
# Processing card 770/845
# Processing card 771/845
# Processing card 772/845
# Processing card 773/845
# Processing card 774/845
# Processing card 775/845
# Processing card 776/845
# Processing card 777/845
# Processing card 778/845
# Processing card 779/845
# Processing card 780/845
# Processing card 781/845
# Processing card 782/845
# Processing card 783/845
# Processing card 784/845
# Processing card 785/845
# Processing card 786/845
# Processing card 787/845
# Processing card 788/845
# Processing card 789/845
# Processing card 790/845
# Processing card 791/845
# Processing card 792/845
# Processing card 793/845
# Processing card 794/845
# Processing card 795/845
# Processing card 796/845
# Processing card 797/845
# Processing card 798/845
# Processing card 799/845
# Processing card 800/845
# Processing card 801/845
# Processing card 802/845
# Processing card 803/845
# Processing card 804/845
# Processing card 805/845
# Processing card 806/845
# Processing card 807/845
# Processing card 808/845
# Processing card 809/845
# Processing card 810/845
# Processing card 811/845
# Processing card 812/845
# Processing card 813/845
# Processing card 814/845
# Processing card 815/845
# Processing card 816/845
# Processing card 817/845
# Processing card 818/845
# Processing card 819/845
# Processing card 820/845
# Processing card 821/845
# Processing card 822/845
# Processing card 823/845
# Processing card 824/845
# Processing card 825/845
# Processing card 826/845
# Processing card 827/845
# Processing card 828/845
# Processing card 829/845
# Processing card 830/845
# Processing card 831/845
# Processing card 832/845
# Processing card 833/845
# Processing card 834/845
# Processing card 835/845
# Processing card 836/845
# Processing card 837/845
# Processing card 838/845
# Processing card 839/845
# Processing card 840/845
# Processing card 841/845
# Processing card 842/845
# Processing card 843/845
# Processing card 844/845
# Processing card 845/845
# Success: Converted 845 cards to i18n format. Saved to './cards_i18n.json'.

# %%
# Generate separate language files for Nuxt.js i18n setup
def generate_language_files(i18n_cards, output_dir='../locales'):
    """Generate separate language files for Nuxt.js i18n setup."""
    # Create output directory if it doesn't exist
    output_path = Path(output_dir)
    output_path.mkdir(parents=True, exist_ok=True)
    
    # Collect all translations by language
    translations_by_lang = {}
    
    for card in i18n_cards:
        for lang, translations in card.get('translations', {}).items():
            if lang not in translations_by_lang:
                translations_by_lang[lang] = {'cards': {}}
            
            card_id = card.get('id', '') or card.get('cardNumber', '')
            if card_id:
                translations_by_lang[lang]['cards'][card_id] = translations
    
    # Save each language file
    for lang, content in translations_by_lang.items():
        lang_file = output_path / f"{lang}.json"
        try:
            with open(lang_file, 'w', encoding='utf-8') as f:
                json.dump(content, f, ensure_ascii=False, indent=2)
            print(f"Language file saved: {lang_file}")
        except Exception as e:
            print(f"Error saving language file {lang}: {str(e)}")
    
    # Generate an English translation template based on Japanese
    if 'ja' in translations_by_lang:
        english_translations = {'cards': {}}
        
        for card_id, ja_translations in translations_by_lang['ja']['cards'].items():
            card_en = {}
            
            # Generate placeholder English translations
            for key, value in ja_translations.items():
                if isinstance(value, list):
                    # Handle nested lists like tags and arts
                    if key == 'tags':
                        card_en[key] = [f"[EN] {tag}" for tag in value]
                    elif key == 'arts':
                        arts_en = []
                        for art in value:
                            art_en = {}
                            for art_key, art_value in art.items():
                                art_en[art_key] = f"[EN] {art_value}"
                            arts_en.append(art_en)
                        card_en[key] = arts_en
                elif isinstance(value, dict):
                    # Handle nested dictionaries like keyword and skills
                    nested_en = {}
                    for nested_key, nested_value in value.items():
                        nested_en[nested_key] = f"[EN] {nested_value}"
                    card_en[key] = nested_en
                else:
                    # Regular string values
                    card_en[key] = f"[EN] {value}"
            
            english_translations['cards'][card_id] = card_en
        
        # Save English template
        en_file = output_path / "en.json"
        try:
            with open(en_file, 'w', encoding='utf-8') as f:
                json.dump(english_translations, f, ensure_ascii=False, indent=2)
            print(f"English template file saved: {en_file}")
        except Exception as e:
            print(f"Error saving English template: {str(e)}")

# %%
# Generate language files
if i18n_cards:
    generate_language_files(i18n_cards)
# Out:
# Language file saved: ../locales/ja.json
# English template file saved: ../locales/en.json

# %% [markdown]
# ## How to Use in Nuxt.js
#
# 1. Install the i18n module:
# ```bash
# npm install @nuxtjs/i18n
# ```
#
# 2. Add the i18n module to your `nuxt.config.ts`:
# ```typescript
# export default defineNuxtConfig({
#   modules: [
#     '@nuxtjs/i18n',
#   ],
#   i18n: {
#     locales: [
#       { code: 'en', iso: 'en-US', file: 'en.json', name: 'English' },
#       { code: 'ja', iso: 'ja-JP', file: 'ja.json', name: '日本語' },
#     ],
#     defaultLocale: 'ja',
#     lazy: true,
#     langDir: 'locales/',
#     strategy: 'prefix_except_default',
#   },
# })
# ```
#
# 3. Access card translations in your Nuxt components:
# ```vue
# <template>
#   <div>
#     <h1>{{ $t(`cards.${cardId}.name`) }}</h1>
#     <p>{{ $t(`cards.${cardId}.cardType`) }}</p>
#     <!-- For nested structures like arts -->
#     <div v-for="(art, index) in $t(`cards.${cardId}.arts`)" :key="index">
#       <h3>{{ art.name }}</h3>
#       <p>{{ art.effect }}</p>
#     </div>
#   </div>
# </template>
#
# <script setup>
# const { cardId } = defineProps(['cardId'])
# </script>
# ```
