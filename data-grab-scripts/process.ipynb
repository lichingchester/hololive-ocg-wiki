# %% [markdown]
# # Process the HTML code into fields

# %%
import json
import re
from bs4 import BeautifulSoup

def extract_structured_data(raw_html):
    """Extract structured data from the raw HTML of a card."""
    soup = BeautifulSoup(raw_html, 'html.parser')
    data = {}
    
    # Extract basic info from the info section
    info_div = soup.find('div', class_='info')
    if info_div:
        # Process main dl elements
        dl_elements = info_div.find_all('dl')
        for dl in dl_elements:
            dt_elements = dl.find_all('dt')
            dd_elements = dl.find_all('dd')
            
            for i in range(len(dt_elements)):
                if i < len(dd_elements):
                    key = dt_elements[i].text.strip()
                    
                    # Check if the DD contains images (like バトンタッチ, 色, etc.)
                    imgs = dd_elements[i].find_all('img')
                    if imgs:
                        # If the value uses images to represent information
                        if key == 'バトンタッチ':
                            # For バトンタッチ, we want to count the number of icons and store image info
                            img_data = []
                            for img in imgs:
                                img_info = {
                                    'alt': img.get('alt', ''),
                                    'src': img.get('src', '')
                                }
                                img_data.append(img_info)
                            
                            # Store both count and raw image data
                            data[key] = {
                                'count': len(imgs),
                                'images': img_data,
                                'raw_html': str(dd_elements[i])
                            }
                        elif key == '色':
                            # For 色, we want the color name from alt and the image info
                            img = imgs[0]
                            data[key] = {
                                'value': img.get('alt', ''),
                                'image': {
                                    'alt': img.get('alt', ''),
                                    'src': img.get('src', '')
                                },
                                'raw_html': str(dd_elements[i])
                            }
                        else:
                            # For other image-based values, store the general structure
                            img_data = []
                            for img in imgs:
                                img_info = {
                                    'alt': img.get('alt', ''),
                                    'src': img.get('src', '')
                                }
                                img_data.append(img_info)
                            data[key] = {
                                'images': img_data,
                                'raw_html': str(dd_elements[i])
                            }
                    # Handle special case for Tags which have links
                    elif key == 'タグ':
                        tags = []
                        for tag_link in dd_elements[i].find_all('a'):
                            tags.append({
                                'name': tag_link.text.strip(),
                                'href': tag_link.get('href', '')
                            })
                        data[key] = tags
                    else:
                        # Regular text content
                        data[key] = dd_elements[i].text.strip()
    
    # Extract Arts information
    arts_divs = soup.find_all('div', class_='sp arts')
    if arts_divs:
        arts_list = []
        for arts_div in arts_divs:
            arts_data = {}
            p_tags = arts_div.find_all('p')
            
            if len(p_tags) > 1:
                arts_content = p_tags[1]
                
                # Get full text content for reference
                arts_data['full_text'] = arts_content.text.strip()
                
                # Extract cost icons (img tags before the name)
                cost_icons = []
                for img in arts_content.find_all('img'):
                    cost_icons.append({
                        'alt': img.get('alt', ''),
                        'src': img.get('src', '')
                    })
                
                arts_data['cost_icons'] = cost_icons
                arts_data['raw_html'] = str(arts_content)
                
                # Try to extract arts name and damage value
                span = arts_content.find('span')
                if span:
                    span_text = span.text.strip()
                    
                    # Use regex to split by Japanese/English full-width space
                    parts = re.split(r'　', span_text)
                    
                    if len(parts) > 0:
                        # Name is the first part
                        arts_data['name'] = parts[0].strip()
                    
                    if len(parts) > 1:
                        # Damage/value is the second part
                        damage_part = parts[1].strip()
                        # Check for additional indicators like '+' or special damage types
                        damage_match = re.search(r'(\d+)([+]?)', damage_part)
                        if damage_match:
                            arts_data['damage'] = damage_match.group(0)
                    
                    # Special damage icons (like 特攻)
                    tokkou_span = span.find('span', class_='tokkou')
                    if tokkou_span:
                        tokkou_imgs = tokkou_span.find_all('img')
                        if tokkou_imgs:
                            tokkou_data = []
                            for img in tokkou_imgs:
                                tokkou_data.append({
                                    'alt': img.get('alt', ''),
                                    'src': img.get('src', '')
                                })
                            arts_data['tokkou'] = tokkou_data
                
                # Extract effect text (everything after the span)
                effect_text = ""
                for content in arts_content.contents:
                    if content.name != 'span':
                        effect_text += str(content)
                
                if effect_text.strip():
                    # Clean up HTML and convert to plain text
                    effect_soup = BeautifulSoup(effect_text, 'html.parser')
                    arts_data['effect'] = effect_soup.text.strip()
            
            arts_list.append(arts_data)
            
        if arts_list:
            data['アーツ'] = arts_list
    
    # Extract Extra information
    extra_div = soup.find('div', class_='extra')
    if extra_div:
        p_tags = extra_div.find_all('p')
        if len(p_tags) > 1:
            data['エクストラ'] = p_tags[1].text.strip()
    
    # Extract keyword abilities
    keyword_div = soup.find('div', class_='keyword')
    if keyword_div:
        p_tags = keyword_div.find_all('p')
        if len(p_tags) > 1:
            keyword_data = {}
            keyword_content = p_tags[1]
            
            # Store full raw HTML
            keyword_data['raw_html'] = str(keyword_content)
            
            # Store full text
            keyword_data['full_text'] = keyword_content.text.strip()
            
            # Check for keyword icon (img tag)
            img = keyword_content.find('img')
            if img:
                keyword_data['icon'] = {
                    'alt': img.get('alt', ''),
                    'src': img.get('src', '')
                }
            
            # Try to extract keyword name from span
            span = keyword_content.find('span')
            if span:
                keyword_name = span.text.strip()
                keyword_data['name'] = keyword_name
                
                # Get effect text (text after the name)
                effect_text = keyword_content.text.replace(span.text, '', 1).strip()
                keyword_data['effect'] = effect_text
            
            data['キーワード'] = keyword_data
    
    # Extract Oshi Skill information
    oshi_div = soup.find('div', class_='oshi skill')
    if oshi_div:
        skill_p = oshi_div.find_all('p')
        if len(skill_p) > 1:
            skill_data = {}
            skill_content = skill_p[1]
            skill_text = skill_content.text.strip()
            
            # Store full text and raw HTML
            skill_data['full_text'] = skill_text
            skill_data['raw_html'] = str(skill_content)
            
            # Extract skill name from span if available
            skill_span = skill_content.find('span')
            if skill_span:
                skill_name = skill_span.text.strip()
                skill_data['name'] = skill_name
                
                # Extract cost and timing using regex
                cost_match = re.search(r'\[ホロパワー：(-\d+)\]', skill_text)
                if cost_match:
                    skill_data['cost'] = cost_match.group(1)
                
                timing_match = re.search(r'\[(ターンに1回|ゲームに1回)\]', skill_text)
                if timing_match:
                    skill_data['timing'] = timing_match.group(1)
                
                # Extract effect (text after the name)
                parts = skill_text.split(skill_name)
                if len(parts) > 1:
                    skill_data['effect'] = parts[1].strip()
            
            data['推しスキル'] = skill_data
    
    # Extract SP Oshi Skill information
    sp_div = soup.find('div', class_='sp skill')
    if sp_div:
        skill_p = sp_div.find_all('p')
        if len(skill_p) > 1:
            skill_data = {}
            skill_content = skill_p[1]
            skill_text = skill_content.text.strip()
            
            # Store full text and raw HTML
            skill_data['full_text'] = skill_text
            skill_data['raw_html'] = str(skill_content)
            
            # Extract skill name from span if available
            skill_span = skill_content.find('span')
            if skill_span:
                skill_name = skill_span.text.strip()
                skill_data['name'] = skill_name
                
                # Extract cost and timing
                cost_match = re.search(r'\[ホロパワー：(-\d+)\]', skill_text)
                if cost_match:
                    skill_data['cost'] = cost_match.group(1)
                
                timing_match = re.search(r'\[(ターンに1回|ゲームに1回)\]', skill_text)
                if timing_match:
                    skill_data['timing'] = timing_match.group(1)
                
                # Extract effect (text after the name)
                parts = skill_text.split(skill_name)
                if len(parts) > 1:
                    skill_data['effect'] = parts[1].strip()
            
            data['SP推しスキル'] = skill_data
    
    # Extract illustrator information
    illustrator_div = soup.find('div', class_='illustrator')
    if illustrator_div:
        # Get illustrator name
        ill_name_p = illustrator_div.find('p', class_='ill-name')
        if ill_name_p:
            span = ill_name_p.find('span')
            if span:
                data['イラストレーター'] = span.text.strip()
        
        # Get card number
        number_p = illustrator_div.find('p', class_='number')
        if number_p:
            span = number_p.find('span')
            if span:
                data['カードナンバー'] = span.text.strip()
    
    # Process for サポート・イベント cards which have ability text
    ability_text = None
    dt_ability = info_div.find('dt', string='能力テキスト') if info_div else None
    if dt_ability:
        dd_ability = dt_ability.find_next_sibling('dd')
        if dd_ability:
            ability_text = dd_ability.text.strip()
            data['能力テキスト'] = ability_text
    
    return data

def process_cards():
    """Process all cards from cards_raw_html.json file into structured data."""
    # Read the raw HTML json file
    with open('./cards_raw_html.json', 'r', encoding='utf-8') as file:
        cards_data = json.load(file)
    
    # Process each card
    structured_cards = []
    
    for i, card in enumerate(cards_data):
        print(f"Processing card {i+1}/{len(cards_data)}")
        
        # Copy the basic info
        processed_card = {}
        
        if 'id' in card:
            processed_card['id'] = card['id']
        
        if 'name' in card:
            processed_card['name'] = card['name']

        if 'image_url' in card:
            processed_card['image_url'] = card['image_url']

        if 'image_path' in card:
            processed_card['image_path'] = card['image_path']
        
        # Extract structured data from HTML
        if 'raw_html' in card:
            structured_data = extract_structured_data(card['raw_html'])
            # Merge the structured data with the basic info
            processed_card.update(structured_data)
        
        structured_cards.append(processed_card)
    
    # Write the structured data to a new JSON file
    with open('./cards_structured.json', 'w', encoding='utf-8') as outfile:
        json.dump(structured_cards, outfile, ensure_ascii=False, indent=2)
    
    print(f"Processed {len(structured_cards)} cards. Output saved to 'cards_structured.json'")
    
    return structured_cards

process_cards()
# Out:
# Processing card 1/845
# Processing card 2/845
# Processing card 3/845
# Processing card 4/845
# Processing card 5/845
# Processing card 6/845
# Processing card 7/845
# Processing card 8/845
# Processing card 9/845
# Processing card 10/845
# Processing card 11/845
# Processing card 12/845
# Processing card 13/845
# Processing card 14/845
# Processing card 15/845
# Processing card 16/845
# Processing card 17/845
# Processing card 18/845
# Processing card 19/845
# Processing card 20/845
# Processing card 21/845
# Processing card 22/845
# Processing card 23/845
# Processing card 24/845
# Processing card 25/845
# Processing card 26/845
# Processing card 27/845
# Processing card 28/845
# Processing card 29/845
# Processing card 30/845
# Processing card 31/845
# Processing card 32/845
# Processing card 33/845
# Processing card 34/845
# Processing card 35/845
# Processing card 766/845
# Processing card 767/845
# Processing card 768/845
# Processing card 769/845
# Processing card 770/845
# Processing card 771/845
# Processing card 772/845
# Processing card 773/845
# Processing card 774/845
# Processing card 775/845
# Processing card 776/845
# Processing card 777/845
# Processing card 778/845
# Processing card 779/845
# Processing card 780/845
# Processing card 781/845
# Processing card 782/845
# Processing card 783/845
# Processing card 784/845
# Processing card 785/845
# Processing card 786/845
# Processing card 787/845
# Processing card 788/845
# Processing card 789/845
# Processing card 790/845
# Processing card 791/845
# Processing card 792/845
# Processing card 793/845
# Processing card 794/845
# Processing card 795/845
# Processing card 796/845
# Processing card 797/845
# Processing card 798/845
# Processing card 799/845
# Processing card 800/845
# Processing card 801/845
# Processing card 802/845
# Processing card 803/845
# Processing card 804/845
# Processing card 805/845
# Processing card 806/845
# Processing card 807/845
# Processing card 808/845
# Processing card 809/845
# Processing card 810/845
# Processing card 811/845
# Processing card 812/845
# Processing card 813/845
# Processing card 814/845
# Processing card 815/845
# Processing card 816/845
# Processing card 817/845
# Processing card 818/845
# Processing card 819/845
# Processing card 820/845
# Processing card 821/845
# Processing card 822/845
# Processing card 823/845
# Processing card 824/845
# Processing card 825/845
# Processing card 826/845
# Processing card 827/845
# Processing card 828/845
# Processing card 829/845
# Processing card 830/845
# Processing card 831/845
# Processing card 832/845
# Processing card 833/845
# Processing card 834/845
# Processing card 835/845
# Processing card 836/845
# Processing card 837/845
# Processing card 838/845
# Processing card 839/845
# Processing card 840/845
# Processing card 841/845
# Processing card 842/845
# Processing card 843/845
# Processing card 844/845
# Processing card 845/845
# Processed 845 cards. Output saved to 'cards_structured.json'
# [{'id': '565',
#   'name': '姫森ルーナ',
#   'image_url': 'https://hololive-official-cardgame.com/wp-content/images/cardlist/hBP03/hBP03-001_OSR.png',
#   'image_path': 'card_images/hBP03-001_OSR.png',
#   'カードタイプ': '推しホロメン',
#   'レアリティ': 'OSR',
#   '収録商品': 'ブースターパック「エリートスパーク」',
#   '色': {'value': '白',
#    'image': {'alt': '白', 'src': '/wp-content/images/texticon/type_white.png'},
#    'raw_html': '<dd><img alt="白" class="" src="/wp-content/images/texticon/type_white.png"/></dd>'},
#   'LIFE': '5',
#   '推しスキル': {'full_text': '[ホロパワー：-2]パソコンならわかるのら[ターンに1回]自分のデッキから、カード名に「パソコン」を含むアイテム1枚を公開し、手札に加える。そしてデッキをシャッフルする。',
#    'raw_html': '<p>[ホロパワー：-2]<span>パソコンならわかるのら</span>[ターンに1回]自分のデッキから、カード名に「パソコン」を含むアイテム1枚を公開し、手札に加える。そしてデッキをシャッフルする。</p>',
#    'name': 'パソコンならわかるのら',
#    'cost': '-2',
#    'timing': 'ターンに1回',
#    'effect': '[ターンに1回]自分のデッキから、カード名に「パソコン」を含むアイテム1枚を公開し、手札に加える。そしてデッキをシャッフルする。'},
#   'SP推しスキル': {'full_text': '[ホロパワー：-2]ルーナイト集合[ゲームに1回]自分のセンターホロメンが〈姫森ルーナ〉の時に使える：自分のデッキから、〈ルーナイト〉1～4枚を公開し、自分のホロメンに割り振って付ける。そしてデッキをシャッフルする。',
#    'raw_html': '<p>[ホロパワー：-2]<span>ルーナイト集合</span>[ゲームに1回]自分のセンターホロメンが〈姫森ルーナ〉の時に使える：自分のデッキから、〈ルーナイト〉1～4枚を公開し、自分のホロメンに割り振って付ける。そしてデッキをシャッフルする。</p>',
#    'name': 'ルーナイト集合',
#    'cost': '-2',
#    'timing': 'ゲームに1回',
#    'effect': '[ゲームに1回]自分のセンターホロメンが〈姫森ルーナ〉の時に使える：自分のデッキから、〈ルーナイト〉1～4枚を公開し、自分のホロメンに割り振って付ける。そしてデッキをシャッフルする。'},
#   'イラストレーター': 'gaha',
#   'カードナンバー': 'hBP03-001'},
#  {'id': '566',
#   'name': '獅白ぼたん',
#   'image_url': 'https://hololive-official-cardgame.com/wp-content/images/cardlist/hBP03/hBP03-002_OSR.png',
#   'image_path': 'card_images/hBP03-002_OSR.png',
#   'カードタイプ': '推しホロメン',
#   'レアリティ': 'OSR',
#   '収録商品': 'ブースターパック「エリートスパーク」',
#   '色': {'value': '緑',
#    'image': {'alt': '緑', 'src': '/wp-content/images/texticon/type_green.png'},
#    'raw_html': '<dd><img alt="緑" class="" src="/wp-content/images/texticon/type_green.png"/></dd>'},
#   'LIFE': '5',
#   '推しスキル': {'full_text': '[ホロパワー：-2]poi[ターンに1回]自分のアーカイブのエール1枚を、自分のバックホロメンの〈獅白ぼたん〉に送る。',
#    'raw_html': '<p>[ホロパワー：-2]<span>poi</span>[ターンに1回]自分のアーカイブのエール1枚を、自分のバックホロメンの〈獅白ぼたん〉に送る。</p>',
#    'name': 'poi',
#    'cost': '-2',
#    'timing': 'ターンに1回',
#    'effect': '[ターンに1回]自分のアーカイブのエール1枚を、自分のバックホロメンの〈獅白ぼたん〉に送る。'},
#   'SP推しスキル': {'full_text': '[ホロパワー：-2]狙撃[ゲームに1回]自分のセンターホロメンの色が緑の時に使える：相手のDebut以外のセンターホロメンに特殊ダメージ100を与える。',
#    'raw_html': '<p>[ホロパワー：-2]<span>狙撃</span>[ゲームに1回]自分のセンターホロメンの色が緑の時に使える：相手のDebut以外のセンターホロメンに特殊ダメージ100を与える。</p>',
#    'name': '狙撃',
#    'cost': '-2',
#    'timing': 'ゲームに1回',
#    'effect': '[ゲームに1回]自分のセンターホロメンの色が緑の時に使える：相手のDebut以外のセンターホロメンに特殊ダメージ100を与える。'},
#   'イラストレーター': 'すなれ',
#   'カードナンバー': 'hBP03-002'},
#  {'id': '567',
#   'name': 'さくらみこ',
#   'image_url': 'https://hololive-official-cardgame.com/wp-content/images/cardlist/hBP03/hBP03-003_OSR.png',
#   'image_path': 'card_images/hBP03-003_OSR.png',
#   'カードタイプ': '推しホロメン',
#   'レアリティ': 'OSR',
#   '収録商品': 'ブースターパック「エリートスパーク」',
#   '色': {'value': '赤',
#    'image': {'alt': '赤', 'src': '/wp-content/images/texticon/type_red.png'},
#    'raw_html': '<dd><img alt="赤" class="" src="/wp-content/images/texticon/type_red.png"/></dd>'},
#   'LIFE': '5',
#   '推しスキル': {'full_text': '[ホロパワー：-2]35P帰ってくるのかッ！？って！[ターンに1回]サイコロを1回振れる：1か2か4か6の時、自分のアーカイブの〈35P〉1枚を手札に戻す。3か5の時、自分のアーカイブの〈35P〉2枚を手札に戻す。',
#    'raw_html': '<p>[ホロパワー：-2]<span>35P帰ってくるのかッ！？って！</span>[ターンに1回]サイコロを1回振れる：1か2か4か6の時、自分のアーカイブの〈35P〉1枚を手札に戻す。3か5の時、自分のアーカイブの〈35P〉2枚を手札に戻す。</p>',
#    'name': '35P帰ってくるのかッ！？って！',
#    'cost': '-2',
#    'timing': 'ターンに1回',
#    'effect': '[ターンに1回]サイコロを1回振れる：1か2か4か6の時、自分のアーカイブの〈35P〉1枚を手札に戻す。3か5の時、自分のアーカイブの〈35P〉2枚を手札に戻す。'},
#   'SP推しスキル': {'full_text': '[ホロパワー：-2]あきらめない心にぇ[ゲームに1回]自分のセンターホロメンの色が赤の時に使える：自分の手札を好きな枚数選んで好きな順でデッキの下に戻す。そして手札が5枚になるまで、自分のデッキを引く。',
#    'raw_html': '<p>[ホロパワー：-2]<span>あきらめない心にぇ</span>[ゲームに1回]自分のセンターホロメンの色が赤の時に使える：自分の手札を好きな枚数選んで好きな順でデッキの下に戻す。そして手札が5枚になるまで、自分のデッキを引く。</p>',
#    'name': 'あきらめない心にぇ',
#    'cost': '-2',
#    'timing': 'ゲームに1回',
#    'effect': '[ゲームに1回]自分のセンターホロメンの色が赤の時に使える：自分の手札を好きな枚数選んで好きな順でデッキの下に戻す。そして手札が5枚になるまで、自分のデッキを引く。'},
#   'イラストレーター': 'kobuta',
#   'カードナンバー': 'hBP03-003'},
#  {'id': '568',
#   'name': 'FUWAMOCO',
#   'image_url': 'https://hololive-official-cardgame.com/wp-content/images/cardlist/hBP03/hBP03-004_OSR.png',
#   'image_path': 'card_images/hBP03-004_OSR.png',
#   'カードタイプ': '推しホロメン',
#   'レアリティ': 'OSR',
#   '収録商品': 'ブースターパック「エリートスパーク」',
#   '色': {'value': '青',
#    'image': {'alt': '青', 'src': '/wp-content/images/texticon/type_blue.png'},
#    'raw_html': '<dd><img alt="青" class="" src="/wp-content/images/texticon/type_blue.png"/></dd>'},
#   'LIFE': '5',
#   '推しスキル': {'full_text': '[ホロパワー：-3]モコちゃん！[ターンに1回]自分のエールデッキの上から1枚を、自分の1stホロメンの〈モココ・アビスガード〉に送る。',
#    'raw_html': '<p>[ホロパワー：-3]<span>モコちゃん！</span>[ターンに1回]自分のエールデッキの上から1枚を、自分の1stホロメンの〈モココ・アビスガード〉に送る。</p>',
#    'name': 'モコちゃん！',
#    'cost': '-3',
#    'timing': 'ターンに1回',
#    'effect': '[ターンに1回]自分のエールデッキの上から1枚を、自分の1stホロメンの〈モココ・アビスガード〉に送る。'},
#   'SP推しスキル': {'full_text': '[ホロパワー：-2]BAU BAU![ゲームに1回]自分の#Adventを持つホロメン1人を選ぶ。このターンの間、選んだホロメンのアーツは、相手のバックホロメンも対象にできる。',
#    'raw_html': '<p>[ホロパワー：-2]<span>BAU BAU!</span>[ゲームに1回]自分の#Adventを持つホロメン1人を選ぶ。このターンの間、選んだホロメンのアーツは、相手のバックホロメンも対象にできる。</p>',
#    'name': 'BAU BAU!',
#    'cost': '-2',
#    'timing': 'ゲームに1回',
#    'effect': '[ゲームに1回]自分の#Adventを持つホロメン1人を選ぶ。このターンの間、選んだホロメンのアーツは、相手のバックホロメンも対象にできる。'},
#   'イラストレーター': 'みゃーこ',
#   'カードナンバー': 'hBP03-004'},
#  {'id': '569',
#   'name': '常闇トワ',
#   'image_url': 'https://hololive-official-cardgame.com/wp-content/images/cardlist/hBP03/hBP03-005_OSR.png',
#   'image_path': 'card_images/hBP03-005_OSR.png',
#   'カードタイプ': '推しホロメン',
#   'レアリティ': 'OSR',
#   '収録商品': 'ブースターパック「エリートスパーク」',
#   '色': {'value': '紫',
#    'image': {'alt': '紫', 'src': '/wp-content/images/texticon/type_purple.png'},
#    'raw_html': '<dd><img alt="紫" class="" src="/wp-content/images/texticon/type_purple.png"/></dd>'},
#   'LIFE': '5',
#   '推しスキル': {'full_text': '[ホロパワー：-2]デビルズヴォイス[ターンに1回]このターンの間、自分の#歌を持つ[センターホロメンとコラボホロメン]のアーツ+20。',
#    'raw_html': '<p>[ホロパワー：-2]<span>デビルズヴォイス</span>[ターンに1回]このターンの間、自分の#歌を持つ[センターホロメンとコラボホロメン]のアーツ+20。</p>',
#    'name': 'デビルズヴォイス',
#    'cost': '-2',
#    'timing': 'ターンに1回',
#    'effect': '[ターンに1回]このターンの間、自分の#歌を持つ[センターホロメンとコラボホロメン]のアーツ+20。'},
#   'SP推しスキル': {'full_text': '[ホロパワー：-2]悪魔的所業[ゲームに1回]相手のターンで、自分の〈常闇トワ〉がダウンした時に使える：相手のセンターホロメンとコラボホロメンのエール2枚ずつを好きな順でエールデッキの下に戻す。',
#    'raw_html': '<p>[ホロパワー：-2]<span>悪魔的所業</span>[ゲームに1回]相手のターンで、自分の〈常闇トワ〉がダウンした時に使える：相手のセンターホロメンとコラボホロメンのエール2枚ずつを好きな順でエールデッキの下に戻す。</p>',
#    'name': '悪魔的所業',
#    'cost': '-2',
#    'timing': 'ゲームに1回',
#    'effect': '[ゲームに1回]相手のターンで、自分の〈常闇トワ〉がダウンした時に使える：相手のセンターホロメンとコラボホロメンのエール2枚ずつを好きな順でエールデッキの下に戻す。'},
#   'イラストレーター': '夕城',
#   'カードナンバー': 'hBP03-005'},
#  {'id': '570',
#   'name': '戌神ころね',
#   'image_url': 'https://hololive-official-cardgame.com/wp-content/images/cardlist/hBP03/hBP03-006_OSR.png',
#   'image_path': 'card_images/hBP03-006_OSR.png',
#   'カードタイプ': '推しホロメン',
#   'レアリティ': 'OSR',
#   '収録商品': 'ブースターパック「エリートスパーク」',
#   '色': {'value': '黄',
#    'image': {'alt': '黄', 'src': '/wp-content/images/texticon/type_yellow.png'},
#    'raw_html': '<dd><img alt="黄" class="" src="/wp-content/images/texticon/type_yellow.png"/></dd>'},
#   'LIFE': '6',
#   '推しスキル': {'full_text': '[ホロパワー：-2]無限の体力[ターンに1回]自分のお休みしている〈戌神ころね〉1人をアクティブにする。',
#    'raw_html': '<p>[ホロパワー：-2]<span>無限の体力</span>[ターンに1回]自分のお休みしている〈戌神ころね〉1人をアクティブにする。</p>',
#    'name': '無限の体力',
#    'cost': '-2',
#    'timing': 'ターンに1回',
#    'effect': '[ターンに1回]自分のお休みしている〈戌神ころね〉1人をアクティブにする。'},
#   'SP推しスキル': {'full_text': '[ホロパワー：-3]ウォウウォウウォウウォウ[ゲームに1回]自分の黄ホロメンがダウンした時に使える：そのホロメンのエール1枚を自分の他のホロメンに付け替え、そのダウンしたホロメンを含め重なっているホロメンの中から1枚を手札に戻す。',
#    'raw_html': '<p>[ホロパワー：-3]<span>ウォウウォウウォウウォウ</span>[ゲームに1回]自分の黄ホロメンがダウンした時に使える：そのホロメンのエール1枚を自分の他のホロメンに付け替え、そのダウンしたホロメンを含め重なっているホロメンの中から1枚を手札に戻す。</p>',
#    'name': 'ウォウウォウウォウウォウ',
#    'cost': '-3',
#    'timing': 'ゲームに1回',
#    'effect': '[ゲームに1回]自分の黄ホロメンがダウンした時に使える：そのホロメンのエール1枚を自分の他のホロメンに付け替え、そのダウンしたホロメンを含め重なっているホロメンの中から1枚を手札に戻す。'},
#   'イラストレーター': 'nima',
#   'カードナンバー': 'hBP03-006'},
#  {'id': '571',
#   'name': '角巻わため',
#   'image_url': 'https://hololive-official-cardgame.com/wp-content/images/cardlist/hBP03/hBP03-007_OSR.png',
#   'image_path': 'card_images/hBP03-007_OSR.png',
#   'カードタイプ': '推しホロメン',
#   'レアリティ': 'OSR',
#   '収録商品': 'ブースターパック「エリートスパーク」',
#   '色': {'value': '黄',
#    'image': {'alt': '黄', 'src': '/wp-content/images/texticon/type_yellow.png'},
#    'raw_html': '<dd><img alt="黄" class="" src="/wp-content/images/texticon/type_yellow.png"/></dd>'},
#   'LIFE': '5',
#   '推しスキル': {'full_text': '[ホロパワー：-2]Member sheep いらっしゃい！[ターンに1回]自分のデッキから、ファン1枚を公開し、手札に加える。そしてデッキをシャッフルする。',
#    'raw_html': '<p>[ホロパワー：-2]<span>Member sheep いらっしゃい！</span>[ターンに1回]自分のデッキから、ファン1枚を公開し、手札に加える。そしてデッキをシャッフルする。</p>',
#    'name': 'Member sheep いらっしゃい！',
#    'cost': '-2',
#    'timing': 'ターンに1回',
#    'effect': '[ターンに1回]自分のデッキから、ファン1枚を公開し、手札に加える。そしてデッキをシャッフルする。'},
#   'SP推しスキル': {'full_text': '[ホロパワー：-2]わためは悪くないよねぇ？[ゲームに1回]自分のエールデッキの上から2枚を、自分の〈角巻わため〉1人に送る。',
#    'raw_html': '<p>[ホロパワー：-2]<span>わためは悪くないよねぇ？</span>[ゲームに1回]自分のエールデッキの上から2枚を、自分の〈角巻わため〉1人に送る。</p>',
#    'name': 'わためは悪くないよねぇ？',
#    'cost': '-2',
#    'timing': 'ゲームに1回',
#    'effect': '[ゲームに1回]自分のエールデッキの上から2枚を、自分の〈角巻わため〉1人に送る。'},
#   'イラストレーター': '望田とうり',
#   'カードナンバー': 'hBP03-007'},
#  {'id': '572',
#   'name': 'アユンダ・リス',
#   'image_url': 'https://hololive-official-cardgame.com/wp-content/images/cardlist/hBP03/hBP03-008_OSR.png',
#   'image_path': 'card_images/hBP03-008_OSR.png',
#   'カードタイプ': '推しホロメン',
#   'レアリティ': 'OSR',
#   '収録商品': 'ブースターパック「エリートスパーク」',
#   '色': {'value': '黄',
#    'image': {'alt': '黄', 'src': '/wp-content/images/texticon/type_yellow.png'},
#    'raw_html': '<dd><img alt="黄" class="" src="/wp-content/images/texticon/type_yellow.png"/></dd>'},
#   'LIFE': '5',
#   '推しスキル': {'full_text': '[ホロパワー：-2]ホロライブID一家[ターンに1回]自分の#ID1期生を持つホロメンがダウンした時に使える：自分のデッキを1枚引く。',
#    'raw_html': '<p>[ホロパワー：-2]<span>ホロライブID一家</span>[ターンに1回]自分の#ID1期生を持つホロメンがダウンした時に使える：自分のデッキを1枚引く。</p>',
#    'name': 'ホロライブID一家',
#    'cost': '-2',
#    'timing': 'ターンに1回',
#    'effect': '[ターンに1回]自分の#ID1期生を持つホロメンがダウンした時に使える：自分のデッキを1枚引く。'},
#   'SP推しスキル': {'full_text': '[ホロパワー：-2]がんばり～リス！[ゲームに1回]このターンの間、自分のステージの〈アユンダ・リス〉全員のアーツ+50。',
#    'raw_html': '<p>[ホロパワー：-2]<span>がんばり～リス！</span>[ゲームに1回]このターンの間、自分のステージの〈アユンダ・リス〉全員のアーツ+50。</p>',
#    'name': 'がんばり～リス！',
#    'cost': '-2',
#    'timing': 'ゲームに1回',
#    'effect': '[ゲームに1回]このターンの間、自分のステージの〈アユンダ・リス〉全員のアーツ+50。'},
#   'イラストレーター': '砂利さや(か)',
#   'カードナンバー': 'hBP03-008'},
#  {'id': '573',
#   'name': '姫森ルーナ',
#   'image_url': 'https://hololive-official-cardgame.com/wp-content/images/cardlist/hBP03/hBP03-009_C.png',
#   'image_path': 'card_images/hBP03-009_C.png',
#   'カードタイプ': 'ホロメン',
#   'タグ': [{'name': '#JP', 'href': '/cardlist/cardsearch?keyword=%23JP'},
#    {'name': '#4期生',
#     'href': '/cardlist/cardsearch?keyword=%234%E6%9C%9F%E7%94%9F'},
#    {'name': '#ベイビー',
#     'href': '/cardlist/cardsearch?keyword=%23%E3%83%99%E3%82%A4%E3%83%93%E3%83%BC'}],
#   'レアリティ': 'C',
#   '収録商品': 'ブースターパック「エリートスパーク」',
#   '色': {'value': '白',
#    'image': {'alt': '白', 'src': '/wp-content/images/texticon/type_white.png'},
#    'raw_html': '<dd><img alt="白" class="" src="/wp-content/images/texticon/type_white.png"/></dd>'},
#   'HP': '90',
#   'Bloomレベル': 'Debut',
#   'バトンタッチ': {'count': 1,
#    'images': [{'alt': '◇',
#      'src': '/wp-content/images/texticon/arts_null.png'}],
#    'raw_html': '<dd><img alt="◇" class="" src="/wp-content/images/texticon/arts_null.png"/></dd>'},
#   'アーツ': [{'full_text': 'みんな～、おりゅ～？\u300010\n自分の〈ルーナイト〉が付いているホロメンがいない時、自分のデッキから、〈ルーナイト〉1枚を公開し、自分のホロメンに付ける。そしてデッキをシャッフルする。',
#     'cost_icons': [{'alt': '◇',
#       'src': '/wp-content/images/texticon/arts_null.png'}],
#     'raw_html': '<p><span><img alt="◇" class="" src="/wp-content/images/texticon/arts_null.png"/>みんな～、おりゅ～？\u300010<span class="tokkou"></span></span>\n自分の〈ルーナイト〉が付いているホロメンがいない時、自分のデッキから、〈ルーナイト〉1枚を公開し、自分のホロメンに付ける。そしてデッキをシャッフルする。</p>',
#     'name': 'みんな～、おりゅ～？',
#     'damage': '10',
#     'effect': '自分の〈ルーナイト〉が付いているホロメンがいない時、自分のデッキから、〈ルーナイト〉1枚を公開し、自分のホロメンに付ける。そしてデッキをシャッフルする。'}],
#   'エクストラ': 'このホロメンはデッキに何枚でも入れられる',
#   'カードナンバー': 'hBP03-009'},
#  {'id': '574',
#   'name': '姫森ルーナ',
#   'image_url': 'https://hololive-official-cardgame.com/wp-content/images/cardlist/hBP03/hBP03-010_U.png',
#   'image_path': 'card_images/hBP03-010_U.png',
#   'カードタイプ': 'ホロメン',
#   'タグ': [{'name': '#JP', 'href': '/cardlist/cardsearch?keyword=%23JP'},
# ...
#   'アーツ': [{'full_text': '輝く彗星\u300060+\nこのホロメンの青エール２枚をアーカイブできる：このホロメンに重なっているホロメン１枚につき、このアーツ+60（このアーツは相手のバックホロメンも対象にできる）。',
#     'cost_icons': [{'alt': '青',
#       'src': '/wp-content/images/texticon/arts_blue.png'},
#      {'alt': '青', 'src': '/wp-content/images/texticon/arts_blue.png'},
#      {'alt': '青', 'src': '/wp-content/images/texticon/arts_blue.png'},
#      {'alt': '◇', 'src': '/wp-content/images/texticon/arts_null.png'},
#      {'alt': '赤+50', 'src': '/wp-content/images/texticon/tokkou_50_red.png'}],
#     'raw_html': '<p><span><img alt="青" class="" src="/wp-content/images/texticon/arts_blue.png"/><img alt="青" class="" src="/wp-content/images/texticon/arts_blue.png"/><img alt="青" class="" src="/wp-content/images/texticon/arts_blue.png"/><img alt="◇" class="" src="/wp-content/images/texticon/arts_null.png"/>輝く彗星\u300060+<span class="tokkou"><img alt="赤+50" class="" src="/wp-content/images/texticon/tokkou_50_red.png"/></span></span>\nこのホロメンの青エール２枚をアーカイブできる：このホロメンに重なっているホロメン１枚につき、このアーツ+60（このアーツは相手のバックホロメンも対象にできる）。</p>',
#     'name': '輝く彗星',
#     'damage': '60+',
#     'tokkou': [{'alt': '赤+50',
#       'src': '/wp-content/images/texticon/tokkou_50_red.png'}],
#     'effect': 'このホロメンの青エール２枚をアーカイブできる：このホロメンに重なっているホロメン１枚につき、このアーツ+60（このアーツは相手のバックホロメンも対象にできる）。'}],
#   'キーワード': {'raw_html': '<p><span><img alt="コラボエフェクト" class="" src="/wp-content/images/texticon/collabEF.png"/>空を駆ける光\u3000</span>\n自分のエールデッキの上から１枚を、自分の青ホロメンに送る。</p>',
#    'full_text': '空を駆ける光\u3000\n自分のエールデッキの上から１枚を、自分の青ホロメンに送る。',
#    'icon': {'alt': 'コラボエフェクト',
#     'src': '/wp-content/images/texticon/collabEF.png'},
#    'name': '空を駆ける光',
#    'effect': '自分のエールデッキの上から１枚を、自分の青ホロメンに送る。'},
#   'カードナンバー': 'hBP01-081'},
#  {'id': '132',
#   'name': 'ムーナ・ホシノヴァ',
#   'image_url': 'https://hololive-official-cardgame.com/wp-content/images/cardlist/hBP01/hBP01-091_UR.png',
#   'image_path': 'card_images/hBP01-091_UR.png',
#   'カードタイプ': 'Buzzホロメン',
#   'タグ': [{'name': '#ID', 'href': '/cardlist/cardsearch?keyword=%23ID'},
#    {'name': '#ID1期生',
#     'href': '/cardlist/cardsearch?keyword=%23ID1%E6%9C%9F%E7%94%9F'},
#    {'name': '#歌', 'href': '/cardlist/cardsearch?keyword=%23%E6%AD%8C'}],
#   'レアリティ': 'UR',
#   '収録商品': 'ブースターパック「ブルーミングレディアンス」',
#   '色': {'value': '青',
#    'image': {'alt': '青', 'src': '/wp-content/images/texticon/type_blue.png'},
#    'raw_html': '<dd><img alt="青" class="" src="/wp-content/images/texticon/type_blue.png"/></dd>'},
#   'HP': '240',
#   'Bloomレベル': '1st',
#   'バトンタッチ': {'count': 2,
#    'images': [{'alt': '◇', 'src': '/wp-content/images/texticon/arts_null.png'},
#     {'alt': '◇', 'src': '/wp-content/images/texticon/arts_null.png'}],
#    'raw_html': '<dd><img alt="◇" class="" src="/wp-content/images/texticon/arts_null.png"/><img alt="◇" class="" src="/wp-content/images/texticon/arts_null.png"/></dd>'},
#   'アーツ': [{'full_text': '月は夜に。\u300050',
#     'cost_icons': [{'alt': '◇',
#       'src': '/wp-content/images/texticon/arts_null.png'},
#      {'alt': '◇', 'src': '/wp-content/images/texticon/arts_null.png'}],
#     'raw_html': '<p><span><img alt="◇" class="" src="/wp-content/images/texticon/arts_null.png"/><img alt="◇" class="" src="/wp-content/images/texticon/arts_null.png"/>月は夜に。\u300050<span class="tokkou"></span></span>\n</p>',
#     'name': '月は夜に。',
#     'damage': '50'},
#    {'full_text': 'ムーンナイトディーバ\u300080\nこのホロメンの[緑エールか青エール]１枚をアーカイブできる：相手のバックホロメン１人に特殊ダメージ30を与える。',
#     'cost_icons': [{'alt': '青',
#       'src': '/wp-content/images/texticon/arts_blue.png'},
#      {'alt': '◇', 'src': '/wp-content/images/texticon/arts_null.png'},
#      {'alt': '◇', 'src': '/wp-content/images/texticon/arts_null.png'}],
#     'raw_html': '<p><span><img alt="青" class="" src="/wp-content/images/texticon/arts_blue.png"/><img alt="◇" class="" src="/wp-content/images/texticon/arts_null.png"/><img alt="◇" class="" src="/wp-content/images/texticon/arts_null.png"/>ムーンナイトディーバ\u300080<span class="tokkou"></span></span>\nこのホロメンの[緑エールか青エール]１枚をアーカイブできる：相手のバックホロメン１人に特殊ダメージ30を与える。</p>',
#     'name': 'ムーンナイトディーバ',
#     'damage': '80',
#     'effect': 'このホロメンの[緑エールか青エール]１枚をアーカイブできる：相手のバックホロメン１人に特殊ダメージ30を与える。'}],
#   'エクストラ': 'このホロメンがダウンした時、自分のライフ-２',
#   'イラストレーター': '高崎律',
#   'カードナンバー': 'hBP01-091'},
#  {'id': '797',
#   'name': '白エール',
#   'image_url': 'https://hololive-official-cardgame.com/wp-content/images/cardlist/hBP03/hY01-004_SY.png',
#   'image_path': 'card_images/hY01-004_SY.png',
#   'カードタイプ': 'エール',
#   'レアリティ': 'SY',
#   '収録商品': 'ブースターパック「エリートスパーク」',
#   '能力テキスト': '■ホロメンがステージから離れる時、そのホロメンのエールすべてをアーカイブする。\n■ホロメンがバトンタッチする時、そのホロメンのエールを指定された枚数アーカイブする。',
#   '色': {'value': '白',
#    'image': {'alt': '白', 'src': '/wp-content/images/texticon/type_white.png'},
#    'raw_html': '<dd><img alt="白" class="" src="/wp-content/images/texticon/type_white.png"/></dd>'},
#   'イラストレーター': 'リズ',
#   'カードナンバー': 'hY01-004'},
#  {'id': '798',
#   'name': '緑エール',
#   'image_url': 'https://hololive-official-cardgame.com/wp-content/images/cardlist/hBP03/hY02-003_SY.png',
#   'image_path': 'card_images/hY02-003_SY.png',
#   'カードタイプ': 'エール',
#   'レアリティ': 'SY',
#   '収録商品': 'ブースターパック「エリートスパーク」',
#   '能力テキスト': '■ホロメンがステージから離れる時、そのホロメンのエールすべてをアーカイブする。\n■ホロメンがバトンタッチする時、そのホロメンのエールを指定された枚数アーカイブする。',
#   '色': {'value': '緑',
#    'image': {'alt': '緑', 'src': '/wp-content/images/texticon/type_green.png'},
#    'raw_html': '<dd><img alt="緑" class="" src="/wp-content/images/texticon/type_green.png"/></dd>'},
#   'イラストレーター': 'リズ',
#   'カードナンバー': 'hY02-003'},
#  {'id': '799',
#   'name': '赤エール',
#   'image_url': 'https://hololive-official-cardgame.com/wp-content/images/cardlist/hBP03/hY03-003_SY.png',
#   'image_path': 'card_images/hY03-003_SY.png',
#   'カードタイプ': 'エール',
#   'レアリティ': 'SY',
#   '収録商品': 'ブースターパック「エリートスパーク」',
#   '能力テキスト': '■ホロメンがステージから離れる時、そのホロメンのエールすべてをアーカイブする。\n■ホロメンがバトンタッチする時、そのホロメンのエールを指定された枚数アーカイブする。',
#   '色': {'value': '赤',
#    'image': {'alt': '赤', 'src': '/wp-content/images/texticon/type_red.png'},
#    'raw_html': '<dd><img alt="赤" class="" src="/wp-content/images/texticon/type_red.png"/></dd>'},
#   'イラストレーター': 'リズ',
#   'カードナンバー': 'hY03-003'},
#  {'id': '800',
#   'name': '青エール',
#   'image_url': 'https://hololive-official-cardgame.com/wp-content/images/cardlist/hBP03/hY04-003_SY.png',
#   'image_path': 'card_images/hY04-003_SY.png',
#   'カードタイプ': 'エール',
#   'レアリティ': 'SY',
#   '収録商品': 'ブースターパック「エリートスパーク」',
#   '能力テキスト': '■ホロメンがステージから離れる時、そのホロメンのエールすべてをアーカイブする。\n■ホロメンがバトンタッチする時、そのホロメンのエールを指定された枚数アーカイブする。',
#   '色': {'value': '青',
#    'image': {'alt': '青', 'src': '/wp-content/images/texticon/type_blue.png'},
#    'raw_html': '<dd><img alt="青" class="" src="/wp-content/images/texticon/type_blue.png"/></dd>'},
#   'イラストレーター': 'リズ',
#   'カードナンバー': 'hY04-003'},
#  {'id': '801',
#   'name': '紫エール',
#   'image_url': 'https://hololive-official-cardgame.com/wp-content/images/cardlist/hBP03/hY05-003_SY.png',
#   'image_path': 'card_images/hY05-003_SY.png',
#   'カードタイプ': 'エール',
#   'レアリティ': 'SY',
#   '収録商品': 'ブースターパック「エリートスパーク」',
#   '能力テキスト': '■ホロメンがステージから離れる時、そのホロメンのエールすべてをアーカイブする。\n■ホロメンがバトンタッチする時、そのホロメンのエールを指定された枚数アーカイブする。',
#   '色': {'value': '紫',
#    'image': {'alt': '紫', 'src': '/wp-content/images/texticon/type_purple.png'},
#    'raw_html': '<dd><img alt="紫" class="" src="/wp-content/images/texticon/type_purple.png"/></dd>'},
#   'イラストレーター': 'リズ',
#   'カードナンバー': 'hY05-003'},
#  {'id': '802',
#   'name': '黄エール',
#   'image_url': 'https://hololive-official-cardgame.com/wp-content/images/cardlist/hBP03/hY06-002_SY.png',
#   'image_path': 'card_images/hY06-002_SY.png',
#   'カードタイプ': 'エール',
#   'レアリティ': 'SY',
#   '収録商品': 'ブースターパック「エリートスパーク」',
#   '能力テキスト': '■ホロメンがステージから離れる時、そのホロメンのエールすべてをアーカイブする。\n■ホロメンがバトンタッチする時、そのホロメンのエールを指定された枚数アーカイブする。',
#   '色': {'value': '黄',
#    'image': {'alt': '黄', 'src': '/wp-content/images/texticon/type_yellow.png'},
#    'raw_html': '<dd><img alt="黄" class="" src="/wp-content/images/texticon/type_yellow.png"/></dd>'},
#   'イラストレーター': 'リズ',
#   'カードナンバー': 'hY06-002'},
#  {'id': '477',
#   'name': '白エール',
#   'image_url': 'https://hololive-official-cardgame.com/wp-content/images/cardlist/hBP02/hY01-003_SY.png',
#   'image_path': 'card_images/hY01-003_SY.png',
#   'カードタイプ': 'エール',
#   'レアリティ': 'SY',
#   '収録商品': 'ブースターパック「クインテットスペクトラム」',
#   '能力テキスト': '■ホロメンがステージから離れる時、そのホロメンのエールすべてをアーカイブする。\n■ホロメンがバトンタッチする時、そのホロメンのエールを指定された枚数アーカイブする。',
#   '色': {'value': '白',
#    'image': {'alt': '白', 'src': '/wp-content/images/texticon/type_white.png'},
#    'raw_html': '<dd><img alt="白" class="" src="/wp-content/images/texticon/type_white.png"/></dd>'},
#   'イラストレーター': 'リズ',
#   'カードナンバー': 'hY01-003'},
#  {'id': '478',
#   'name': '緑エール',
#   'image_url': 'https://hololive-official-cardgame.com/wp-content/images/cardlist/hBP02/hY02-002_SY.png',
#   'image_path': 'card_images/hY02-002_SY.png',
#   'カードタイプ': 'エール',
#   'レアリティ': 'SY',
#   '収録商品': 'ブースターパック「クインテットスペクトラム」',
#   '能力テキスト': '■ホロメンがステージから離れる時、そのホロメンのエールすべてをアーカイブする。\n■ホロメンがバトンタッチする時、そのホロメンのエールを指定された枚数アーカイブする。',
#   '色': {'value': '緑',
#    'image': {'alt': '緑', 'src': '/wp-content/images/texticon/type_green.png'},
#    'raw_html': '<dd><img alt="緑" class="" src="/wp-content/images/texticon/type_green.png"/></dd>'},
#   'イラストレーター': 'リズ',
#   'カードナンバー': 'hY02-002'},
#  {'id': '479',
#   'name': '赤エール',
#   'image_url': 'https://hololive-official-cardgame.com/wp-content/images/cardlist/hBP02/hY03-002_SY.png',
#   'image_path': 'card_images/hY03-002_SY.png',
#   'カードタイプ': 'エール',
#   'レアリティ': 'SY',
#   '収録商品': 'ブースターパック「クインテットスペクトラム」',
#   '能力テキスト': '■ホロメンがステージから離れる時、そのホロメンのエールすべてをアーカイブする。\n■ホロメンがバトンタッチする時、そのホロメンのエールを指定された枚数アーカイブする。',
#   '色': {'value': '赤',
#    'image': {'alt': '赤', 'src': '/wp-content/images/texticon/type_red.png'},
#    'raw_html': '<dd><img alt="赤" class="" src="/wp-content/images/texticon/type_red.png"/></dd>'},
#   'イラストレーター': 'リズ',
#   'カードナンバー': 'hY03-002'},
#  {'id': '480',
#   'name': '青エール',
#   'image_url': 'https://hololive-official-cardgame.com/wp-content/images/cardlist/hBP02/hY04-002_SY.png',
#   'image_path': 'card_images/hY04-002_SY.png',
#   'カードタイプ': 'エール',
#   'レアリティ': 'SY',
#   '収録商品': 'ブースターパック「クインテットスペクトラム」',
#   '能力テキスト': '■ホロメンがステージから離れる時、そのホロメンのエールすべてをアーカイブする。\n■ホロメンがバトンタッチする時、そのホロメンのエールを指定された枚数アーカイブする。',
#   '色': {'value': '青',
#    'image': {'alt': '青', 'src': '/wp-content/images/texticon/type_blue.png'},
#    'raw_html': '<dd><img alt="青" class="" src="/wp-content/images/texticon/type_blue.png"/></dd>'},
#   'イラストレーター': 'リズ',
#   'カードナンバー': 'hY04-002'},
#  {'id': '481',
#   'name': '紫エール',
#   'image_url': 'https://hololive-official-cardgame.com/wp-content/images/cardlist/hBP02/hY05-002_SY.png',
#   'image_path': 'card_images/hY05-002_SY.png',
#   'カードタイプ': 'エール',
#   'レアリティ': 'SY',
#   '収録商品': 'ブースターパック「クインテットスペクトラム」',
#   '能力テキスト': '■ホロメンがステージから離れる時、そのホロメンのエールすべてをアーカイブする。\n■ホロメンがバトンタッチする時、そのホロメンのエールを指定された枚数アーカイブする。',
#   '色': {'value': '紫',
#    'image': {'alt': '紫', 'src': '/wp-content/images/texticon/type_purple.png'},
#    'raw_html': '<dd><img alt="紫" class="" src="/wp-content/images/texticon/type_purple.png"/></dd>'},
#   'イラストレーター': 'リズ',
#   'カードナンバー': 'hY05-002'},
#  {'id': '196',
#   'name': '白エール',
#   'image_url': 'https://hololive-official-cardgame.com/wp-content/images/cardlist/hPR/hY01-002_P.png',
#   'image_path': 'card_images/hY01-002_P.png',
#   'カードタイプ': 'エール',
#   'レアリティ': 'P',
#   '収録商品': 'PRカード',
#   '能力テキスト': '■ホロメンがステージから離れる時、そのホロメンのエールすべてをアーカイブする。\n■ホロメンがバトンタッチする時、そのホロメンのエールを指定された枚数アーカイブする。',
#   '色': {'value': '白',
#    'image': {'alt': '白', 'src': '/wp-content/images/texticon/type_white.png'},
#    'raw_html': '<dd><img alt="白" class="" src="/wp-content/images/texticon/type_white.png"/></dd>'},
#   'イラストレーター': '餡こたく',
#   'カードナンバー': 'hY01-002'},
#  {'id': '805',
#   'name': '白エール',
#   'image_url': 'https://hololive-official-cardgame.com/wp-content/images/cardlist/hPR/hY01-005_P.png',
#   'image_path': 'card_images/hY01-005_P.png',
#   'カードタイプ': 'エール',
#   'レアリティ': 'P',
#   '収録商品': 'PRカード',
#   '能力テキスト': '■ホロメンがステージから離れる時、そのホロメンのエールすべてをアーカイブする。\n■ホロメンがバトンタッチする時、そのホロメンのエールを指定された枚数アーカイブする。',
#   '色': {'value': '白',
#    'image': {'alt': '白', 'src': '/wp-content/images/texticon/type_white.png'},
#    'raw_html': '<dd><img alt="白" class="" src="/wp-content/images/texticon/type_white.png"/></dd>'},
#   'イラストレーター': 'しろみにみ',
#   'カードナンバー': 'hY01-005'},
#  {'id': '806',
#   'name': '緑エール',
#   'image_url': 'https://hololive-official-cardgame.com/wp-content/images/cardlist/hPR/hY02-004_P.png',
#   'image_path': 'card_images/hY02-004_P.png',
#   'カードタイプ': 'エール',
#   'レアリティ': 'P',
#   '収録商品': 'PRカード',
#   '能力テキスト': '■ホロメンがステージから離れる時、そのホロメンのエールすべてをアーカイブする。\n■ホロメンがバトンタッチする時、そのホロメンのエールを指定された枚数アーカイブする。',
#   '色': {'value': '緑',
#    'image': {'alt': '緑', 'src': '/wp-content/images/texticon/type_green.png'},
#    'raw_html': '<dd><img alt="緑" class="" src="/wp-content/images/texticon/type_green.png"/></dd>'},
#   'イラストレーター': 'しろみにみ',
#   'カードナンバー': 'hY02-004'},
#  {'id': '837',
#   'name': '赤エール',
#   'image_url': 'https://hololive-official-cardgame.com/wp-content/images/cardlist/hPR/hY03-005_P.png',
#   'image_path': 'card_images/hY03-005_P.png',
#   'カードタイプ': 'エール',
#   'レアリティ': 'P',
#   '収録商品': 'PRカード',
#   '能力テキスト': '■ホロメンがステージから離れる時、そのホロメンのエールすべてをアーカイブする。\n■ホロメンがバトンタッチする時、そのホロメンのエールを指定された枚数アーカイブする。',
#   '色': {'value': '赤',
#    'image': {'alt': '赤', 'src': '/wp-content/images/texticon/type_red.png'},
#    'raw_html': '<dd><img alt="赤" class="" src="/wp-content/images/texticon/type_red.png"/></dd>'},
#   'カードナンバー': 'hY03-005'},
#  {'id': '838',
#   'name': '赤エール',
#   'image_url': 'https://hololive-official-cardgame.com/wp-content/images/cardlist/hPR/hY03-006_P.png',
#   'image_path': 'card_images/hY03-006_P.png',
#   'カードタイプ': 'エール',
#   'レアリティ': 'P',
#   '収録商品': 'PRカード',
#   '能力テキスト': '■ホロメンがステージから離れる時、そのホロメンのエールすべてをアーカイブする。\n■ホロメンがバトンタッチする時、そのホロメンのエールを指定された枚数アーカイブする。',
#   '色': {'value': '赤',
#    'image': {'alt': '赤', 'src': '/wp-content/images/texticon/type_red.png'},
#    'raw_html': '<dd><img alt="赤" class="" src="/wp-content/images/texticon/type_red.png"/></dd>'},
#   'カードナンバー': 'hY03-006'},
#  {'id': '839',
#   'name': '赤エール',
#   'image_url': 'https://hololive-official-cardgame.com/wp-content/images/cardlist/hPR/hY03-007_P.png',
#   'image_path': 'card_images/hY03-007_P.png',
#   'カードタイプ': 'エール',
#   'レアリティ': 'P',
#   '収録商品': 'PRカード',
#   '能力テキスト': '■ホロメンがステージから離れる時、そのホロメンのエールすべてをアーカイブする。\n■ホロメンがバトンタッチする時、そのホロメンのエールを指定された枚数アーカイブする。',
#   '色': {'value': '赤',
#    'image': {'alt': '赤', 'src': '/wp-content/images/texticon/type_red.png'},
#    'raw_html': '<dd><img alt="赤" class="" src="/wp-content/images/texticon/type_red.png"/></dd>'},
#   'カードナンバー': 'hY03-007'},
#  {'id': '840',
#   'name': '赤エール',
#   'image_url': 'https://hololive-official-cardgame.com/wp-content/images/cardlist/hPR/hY03-008_P.png',
#   'image_path': 'card_images/hY03-008_P.png',
#   'カードタイプ': 'エール',
#   'レアリティ': 'P',
#   '収録商品': 'PRカード',
#   '能力テキスト': '■ホロメンがステージから離れる時、そのホロメンのエールすべてをアーカイブする。\n■ホロメンがバトンタッチする時、そのホロメンのエールを指定された枚数アーカイブする。',
#   '色': {'value': '赤',
#    'image': {'alt': '赤', 'src': '/wp-content/images/texticon/type_red.png'},
#    'raw_html': '<dd><img alt="赤" class="" src="/wp-content/images/texticon/type_red.png"/></dd>'},
#   'カードナンバー': 'hY03-008'},
#  {'id': '807',
#   'name': '青エール',
#   'image_url': 'https://hololive-official-cardgame.com/wp-content/images/cardlist/hPR/hY04-004_P.png',
#   'image_path': 'card_images/hY04-004_P.png',
#   'カードタイプ': 'エール',
#   'レアリティ': 'P',
#   '収録商品': 'PRカード',
#   '能力テキスト': '■ホロメンがステージから離れる時、そのホロメンのエールすべてをアーカイブする。\n■ホロメンがバトンタッチする時、そのホロメンのエールを指定された枚数アーカイブする。',
#   '色': {'value': '青',
#    'image': {'alt': '青', 'src': '/wp-content/images/texticon/type_blue.png'},
#    'raw_html': '<dd><img alt="青" class="" src="/wp-content/images/texticon/type_blue.png"/></dd>'},
#   'イラストレーター': 'しろみにみ',
#   'カードナンバー': 'hY04-004'},
#  {'id': '808',
#   'name': '黄エール',
#   'image_url': 'https://hololive-official-cardgame.com/wp-content/images/cardlist/hPR/hY06-003_P.png',
#   'image_path': 'card_images/hY06-003_P.png',
#   'カードタイプ': 'エール',
#   'レアリティ': 'P',
#   '収録商品': 'PRカード',
#   '能力テキスト': '■ホロメンがステージから離れる時、そのホロメンのエールすべてをアーカイブする。\n■ホロメンがバトンタッチする時、そのホロメンのエールを指定された枚数アーカイブする。',
#   '色': {'value': '黄',
#    'image': {'alt': '黄', 'src': '/wp-content/images/texticon/type_yellow.png'},
#    'raw_html': '<dd><img alt="黄" class="" src="/wp-content/images/texticon/type_yellow.png"/></dd>'},
#   'イラストレーター': 'しろみにみ',
#   'カードナンバー': 'hY06-003'}]
