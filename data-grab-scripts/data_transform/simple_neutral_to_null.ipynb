# %%
#!/usr/bin/env python3
"""
Simple script to replace "neutral" with "null" in cards_i18n.json
"""

import json
import os
import shutil
from datetime import datetime

# Paths - using current working directory instead of __file__
PROJECT_ROOT = os.getcwd()  # Use current working directory as base
# Adjust these paths based on your actual directory structure
DATA_FILE = os.path.join(PROJECT_ROOT, "../../data", "cards_i18n.json")
BACKUP_DIR = os.path.join(PROJECT_ROOT, "backups")

# Create backup directory if it doesn't exist
os.makedirs(BACKUP_DIR, exist_ok=True)

# Create backup filename with timestamp
timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
BACKUP_FILE = os.path.join(BACKUP_DIR, f"cards_i18n_backup_{timestamp}.json")

# Print info
print("Starting script...")
print(f"Data file: {DATA_FILE}")
print(f"Backup file: {BACKUP_FILE}")

# Create backup
shutil.copy2(DATA_FILE, BACKUP_FILE)
print(f"Created backup at: {BACKUP_FILE}")

# Load the data
with open(DATA_FILE, 'r', encoding='utf-8') as f:
    cards_data = json.load(f)

print(f"Loaded {len(cards_data)} cards from {DATA_FILE}")

# Replace neutral with null
cards_modified = 0
neutral_count = 0

for card in cards_data:
    card_modified = False
    
    if "arts" in card and isinstance(card["arts"], list):
        for art_index, art in enumerate(card["arts"]):
            if "costTypes" in art and isinstance(art["costTypes"], list):
                for cost_index, cost in enumerate(art["costTypes"]):
                    if cost == "neutral":
                        card_id = card.get("id", "unknown")
                        print(f"Card {card_id}, Art #{art_index+1}, Cost #{cost_index+1}: Changing 'neutral' to null")
                        art["costTypes"][cost_index] = "null"
                        neutral_count += 1
                        card_modified = True
    
    if card_modified:
        cards_modified += 1

print(f"\nReplaced {neutral_count} instances of 'neutral' with null in {cards_modified} cards")

# Save the updated data
with open(DATA_FILE, 'w', encoding='utf-8') as f:
    json.dump(cards_data, f, ensure_ascii=False, indent=2)

print(f"Saved updated data to {DATA_FILE}")

# Verify
null_count = 0
remaining_neutral = 0

for card in cards_data:
    if "arts" in card and isinstance(card["arts"], list):
        for art in card["arts"]:
            if "costTypes" in art and isinstance(art["costTypes"], list):
                for cost in art["costTypes"]:
                    if cost == "neutral":
                        remaining_neutral += 1
                    if cost == "null":  # Fixed comparison (was using 'is' instead of '==')
                        null_count += 1

print(f"\nVerification results:")
print(f"- Remaining 'neutral' values: {remaining_neutral}")
print(f"- Null values found: {null_count}")

print("\nScript completed!")
# Out:
# Starting script...
# Data file: /Users/chingli/lichingchester/projects/hololive-ocg-wiki/data-grab-scripts/data_transform/../../data/cards_i18n.json
# Backup file: /Users/chingli/lichingchester/projects/hololive-ocg-wiki/data-grab-scripts/data_transform/backups/cards_i18n_backup_20250528_204906.json
# Created backup at: /Users/chingli/lichingchester/projects/hololive-ocg-wiki/data-grab-scripts/data_transform/backups/cards_i18n_backup_20250528_204906.json
# Loaded 845 cards from /Users/chingli/lichingchester/projects/hololive-ocg-wiki/data-grab-scripts/data_transform/../../data/cards_i18n.json
# Card 573, Art #1, Cost #1: Changing 'neutral' to null
# Card 575, Art #2, Cost #2: Changing 'neutral' to null
# Card 576, Art #1, Cost #2: Changing 'neutral' to null
# Card 578, Art #1, Cost #3: Changing 'neutral' to null
# Card 579, Art #1, Cost #2: Changing 'neutral' to null
# Card 579, Art #1, Cost #3: Changing 'neutral' to null
# Card 580, Art #1, Cost #1: Changing 'neutral' to null
# Card 582, Art #2, Cost #2: Changing 'neutral' to null
# Card 583, Art #1, Cost #1: Changing 'neutral' to null
# Card 584, Art #1, Cost #2: Changing 'neutral' to null
# Card 585, Art #1, Cost #2: Changing 'neutral' to null
# Card 585, Art #1, Cost #3: Changing 'neutral' to null
# Card 587, Art #1, Cost #2: Changing 'neutral' to null
# Card 587, Art #1, Cost #3: Changing 'neutral' to null
# Card 588, Art #1, Cost #2: Changing 'neutral' to null
# Card 588, Art #1, Cost #3: Changing 'neutral' to null
# Card 588, Art #1, Cost #4: Changing 'neutral' to null
# Card 589, Art #1, Cost #1: Changing 'neutral' to null
# Card 590, Art #1, Cost #2: Changing 'neutral' to null
# Card 591, Art #1, Cost #1: Changing 'neutral' to null
# Card 591, Art #2, Cost #2: Changing 'neutral' to null
# Card 592, Art #1, Cost #1: Changing 'neutral' to null
# Card 592, Art #2, Cost #2: Changing 'neutral' to null
# Card 593, Art #1, Cost #2: Changing 'neutral' to null
# Card 594, Art #1, Cost #2: Changing 'neutral' to null
# Card 594, Art #1, Cost #3: Changing 'neutral' to null
# Card 595, Art #1, Cost #1: Changing 'neutral' to null
# Card 596, Art #1, Cost #2: Changing 'neutral' to null
# Card 597, Art #1, Cost #1: Changing 'neutral' to null
# Card 598, Art #1, Cost #2: Changing 'neutral' to null
# Card 599, Art #1, Cost #2: Changing 'neutral' to null
# Card 600, Art #1, Cost #2: Changing 'neutral' to null
# Card 601, Art #1, Cost #1: Changing 'neutral' to null
# Card 602, Art #1, Cost #1: Changing 'neutral' to null
# Card 604, Art #1, Cost #1: Changing 'neutral' to null
# Card 605, Art #1, Cost #1: Changing 'neutral' to null
# Card 605, Art #2, Cost #2: Changing 'neutral' to null
# Card 606, Art #1, Cost #1: Changing 'neutral' to null
# Card 606, Art #1, Cost #2: Changing 'neutral' to null
# Card 607, Art #2, Cost #3: Changing 'neutral' to null
# Card 608, Art #1, Cost #2: Changing 'neutral' to null
# Card 609, Art #1, Cost #2: Changing 'neutral' to null
# Card 610, Art #1, Cost #1: Changing 'neutral' to null
# Card 610, Art #2, Cost #1: Changing 'neutral' to null
# Card 610, Art #2, Cost #2: Changing 'neutral' to null
# Card 611, Art #1, Cost #2: Changing 'neutral' to null
# Card 612, Art #1, Cost #1: Changing 'neutral' to null
# Card 612, Art #2, Cost #1: Changing 'neutral' to null
# Card 612, Art #2, Cost #2: Changing 'neutral' to null
# Card 613, Art #1, Cost #2: Changing 'neutral' to null
# Card 613, Art #1, Cost #3: Changing 'neutral' to null
# Card 614, Art #1, Cost #1: Changing 'neutral' to null
# Card 614, Art #1, Cost #2: Changing 'neutral' to null
# Card 615, Art #1, Cost #1: Changing 'neutral' to null
# Card 617, Art #1, Cost #1: Changing 'neutral' to null
# Card 617, Art #2, Cost #2: Changing 'neutral' to null
# Card 618, Art #1, Cost #1: Changing 'neutral' to null
# Card 619, Art #2, Cost #2: Changing 'neutral' to null
# Card 620, Art #2, Cost #3: Changing 'neutral' to null
# Card 621, Art #1, Cost #1: Changing 'neutral' to null
# Card 622, Art #1, Cost #1: Changing 'neutral' to null
# Card 622, Art #2, Cost #2: Changing 'neutral' to null
# Card 623, Art #1, Cost #1: Changing 'neutral' to null
# Card 624, Art #1, Cost #1: Changing 'neutral' to null
# Card 625, Art #1, Cost #1: Changing 'neutral' to null
# Card 625, Art #2, Cost #1: Changing 'neutral' to null
# Card 625, Art #2, Cost #2: Changing 'neutral' to null
# Card 625, Art #2, Cost #3: Changing 'neutral' to null
# Card 628, Art #1, Cost #2: Changing 'neutral' to null
# Card 628, Art #2, Cost #1: Changing 'neutral' to null
# Card 628, Art #2, Cost #2: Changing 'neutral' to null
# Card 628, Art #2, Cost #3: Changing 'neutral' to null
# Card 629, Art #1, Cost #1: Changing 'neutral' to null
# Card 629, Art #1, Cost #2: Changing 'neutral' to null
# Card 630, Art #1, Cost #3: Changing 'neutral' to null
# Card 631, Art #1, Cost #1: Changing 'neutral' to null
# Card 633, Art #2, Cost #1: Changing 'neutral' to null
# Card 633, Art #2, Cost #2: Changing 'neutral' to null
# Card 633, Art #2, Cost #3: Changing 'neutral' to null
# Card 634, Art #1, Cost #1: Changing 'neutral' to null
# Card 634, Art #1, Cost #2: Changing 'neutral' to null
# Card 635, Art #1, Cost #2: Changing 'neutral' to null
# Card 636, Art #1, Cost #2: Changing 'neutral' to null
# Card 636, Art #1, Cost #3: Changing 'neutral' to null
# Card 637, Art #1, Cost #1: Changing 'neutral' to null
# Card 637, Art #2, Cost #1: Changing 'neutral' to null
# Card 637, Art #2, Cost #2: Changing 'neutral' to null
# Card 637, Art #2, Cost #3: Changing 'neutral' to null
# Card 638, Art #1, Cost #1: Changing 'neutral' to null
# Card 639, Art #1, Cost #1: Changing 'neutral' to null
# Card 639, Art #2, Cost #2: Changing 'neutral' to null
# Card 639, Art #2, Cost #3: Changing 'neutral' to null
# Card 640, Art #1, Cost #1: Changing 'neutral' to null
# Card 641, Art #1, Cost #2: Changing 'neutral' to null
# Card 642, Art #1, Cost #2: Changing 'neutral' to null
# Card 642, Art #1, Cost #3: Changing 'neutral' to null
# Card 643, Art #1, Cost #2: Changing 'neutral' to null
# Card 644, Art #1, Cost #1: Changing 'neutral' to null
# Card 644, Art #2, Cost #1: Changing 'neutral' to null
# Card 644, Art #2, Cost #2: Changing 'neutral' to null
# Card 644, Art #2, Cost #3: Changing 'neutral' to null
# Card 645, Art #1, Cost #1: Changing 'neutral' to null
# Card 646, Art #1, Cost #2: Changing 'neutral' to null
# Card 646, Art #1, Cost #3: Changing 'neutral' to null
# Card 647, Art #1, Cost #2: Changing 'neutral' to null
# Card 647, Art #1, Cost #3: Changing 'neutral' to null
# Card 647, Art #1, Cost #4: Changing 'neutral' to null
# Card 547, Art #1, Cost #1: Changing 'neutral' to null
# Card 547, Art #2, Cost #1: Changing 'neutral' to null
# Card 547, Art #2, Cost #2: Changing 'neutral' to null
# Card 547, Art #2, Cost #3: Changing 'neutral' to null
# Card 550, Art #2, Cost #2: Changing 'neutral' to null
# Card 551, Art #1, Cost #1: Changing 'neutral' to null
# Card 552, Art #1, Cost #2: Changing 'neutral' to null
# Card 553, Art #1, Cost #2: Changing 'neutral' to null
# Card 554, Art #1, Cost #2: Changing 'neutral' to null
# Card 554, Art #1, Cost #3: Changing 'neutral' to null
# Card 555, Art #1, Cost #1: Changing 'neutral' to null
# Card 556, Art #1, Cost #1: Changing 'neutral' to null
# Card 557, Art #1, Cost #1: Changing 'neutral' to null
# Card 558, Art #1, Cost #1: Changing 'neutral' to null
# Card 533, Art #1, Cost #1: Changing 'neutral' to null
# Card 538, Art #1, Cost #2: Changing 'neutral' to null
# Card 534, Art #1, Cost #1: Changing 'neutral' to null
# Card 536, Art #1, Cost #2: Changing 'neutral' to null
# Card 539, Art #1, Cost #2: Changing 'neutral' to null
# Card 540, Art #1, Cost #2: Changing 'neutral' to null
# Card 540, Art #1, Cost #3: Changing 'neutral' to null
# Card 541, Art #1, Cost #1: Changing 'neutral' to null
# Card 542, Art #1, Cost #1: Changing 'neutral' to null
# Card 543, Art #1, Cost #1: Changing 'neutral' to null
# Card 518, Art #1, Cost #1: Changing 'neutral' to null
# Card 519, Art #1, Cost #1: Changing 'neutral' to null
# Card 520, Art #1, Cost #2: Changing 'neutral' to null
# Card 521, Art #2, Cost #1: Changing 'neutral' to null
# Card 521, Art #2, Cost #2: Changing 'neutral' to null
# Card 522, Art #1, Cost #1: Changing 'neutral' to null
# Card 522, Art #2, Cost #2: Changing 'neutral' to null
# Card 523, Art #1, Cost #1: Changing 'neutral' to null
# Card 525, Art #1, Cost #3: Changing 'neutral' to null
# Card 526, Art #1, Cost #1: Changing 'neutral' to null
# Card 527, Art #1, Cost #1: Changing 'neutral' to null
# Card 528, Art #1, Cost #1: Changing 'neutral' to null
# Card 529, Art #1, Cost #1: Changing 'neutral' to null
# Card 254, Art #1, Cost #1: Changing 'neutral' to null
# Card 255, Art #1, Cost #2: Changing 'neutral' to null
# Card 257, Art #2, Cost #2: Changing 'neutral' to null
# Card 258, Art #1, Cost #2: Changing 'neutral' to null
# Card 259, Art #1, Cost #1: Changing 'neutral' to null
# Card 259, Art #1, Cost #2: Changing 'neutral' to null
# Card 260, Art #1, Cost #2: Changing 'neutral' to null
# Card 260, Art #2, Cost #3: Changing 'neutral' to null
# Card 261, Art #1, Cost #2: Changing 'neutral' to null
# Card 261, Art #2, Cost #3: Changing 'neutral' to null
# Card 262, Art #1, Cost #1: Changing 'neutral' to null
# Card 262, Art #1, Cost #2: Changing 'neutral' to null
# Card 263, Art #1, Cost #1: Changing 'neutral' to null
# Card 240, Art #1, Cost #1: Changing 'neutral' to null
# Card 242, Art #1, Cost #1: Changing 'neutral' to null
# Card 243, Art #1, Cost #1: Changing 'neutral' to null
# Card 243, Art #2, Cost #2: Changing 'neutral' to null
# Card 244, Art #2, Cost #2: Changing 'neutral' to null
# Card 245, Art #1, Cost #1: Changing 'neutral' to null
# Card 246, Art #1, Cost #2: Changing 'neutral' to null
# Card 247, Art #1, Cost #2: Changing 'neutral' to null
# Card 247, Art #2, Cost #3: Changing 'neutral' to null
# Card 247, Art #2, Cost #4: Changing 'neutral' to null
# Card 248, Art #1, Cost #1: Changing 'neutral' to null
# Card 249, Art #1, Cost #1: Changing 'neutral' to null
# Card 249, Art #2, Cost #1: Changing 'neutral' to null
# Card 249, Art #2, Cost #2: Changing 'neutral' to null
# Card 227, Art #1, Cost #1: Changing 'neutral' to null
# Card 229, Art #1, Cost #1: Changing 'neutral' to null
# Card 229, Art #2, Cost #2: Changing 'neutral' to null
# Card 231, Art #1, Cost #1: Changing 'neutral' to null
# Card 232, Art #1, Cost #2: Changing 'neutral' to null
# Card 232, Art #2, Cost #3: Changing 'neutral' to null
# Card 233, Art #2, Cost #3: Changing 'neutral' to null
# Card 234, Art #1, Cost #1: Changing 'neutral' to null
# Card 235, Art #1, Cost #1: Changing 'neutral' to null
# Card 275, Art #1, Cost #1: Changing 'neutral' to null
# Card 277, Art #2, Cost #2: Changing 'neutral' to null
# Card 278, Art #1, Cost #1: Changing 'neutral' to null
# Card 279, Art #1, Cost #2: Changing 'neutral' to null
# Card 280, Art #1, Cost #3: Changing 'neutral' to null
# Card 281, Art #1, Cost #1: Changing 'neutral' to null
# Card 282, Art #1, Cost #1: Changing 'neutral' to null
# Card 282, Art #2, Cost #2: Changing 'neutral' to null
# Card 283, Art #1, Cost #1: Changing 'neutral' to null
# Card 283, Art #1, Cost #2: Changing 'neutral' to null
# Card 284, Art #1, Cost #1: Changing 'neutral' to null
# Card 284, Art #1, Cost #2: Changing 'neutral' to null
# Card 284, Art #2, Cost #2: Changing 'neutral' to null
# Card 284, Art #2, Cost #3: Changing 'neutral' to null
# Card 285, Art #1, Cost #1: Changing 'neutral' to null
# Card 286, Art #1, Cost #1: Changing 'neutral' to null
# Card 287, Art #1, Cost #2: Changing 'neutral' to null
# Card 288, Art #1, Cost #1: Changing 'neutral' to null
# Card 289, Art #1, Cost #2: Changing 'neutral' to null
# Card 290, Art #1, Cost #2: Changing 'neutral' to null
# Card 290, Art #1, Cost #3: Changing 'neutral' to null
# Card 290, Art #1, Cost #4: Changing 'neutral' to null
# Card 291, Art #1, Cost #1: Changing 'neutral' to null
# Card 292, Art #1, Cost #1: Changing 'neutral' to null
# Card 292, Art #2, Cost #2: Changing 'neutral' to null
# Card 293, Art #1, Cost #1: Changing 'neutral' to null
# Card 294, Art #1, Cost #2: Changing 'neutral' to null
# Card 295, Art #1, Cost #1: Changing 'neutral' to null
# Card 296, Art #1, Cost #2: Changing 'neutral' to null
# Card 297, Art #2, Cost #2: Changing 'neutral' to null
# Card 298, Art #1, Cost #1: Changing 'neutral' to null
# Card 299, Art #1, Cost #1: Changing 'neutral' to null
# Card 299, Art #1, Cost #2: Changing 'neutral' to null
# Card 300, Art #1, Cost #2: Changing 'neutral' to null
# Card 300, Art #1, Cost #3: Changing 'neutral' to null
# Card 301, Art #1, Cost #2: Changing 'neutral' to null
# Card 301, Art #2, Cost #2: Changing 'neutral' to null
# Card 301, Art #2, Cost #3: Changing 'neutral' to null
# Card 302, Art #1, Cost #1: Changing 'neutral' to null
# Card 303, Art #1, Cost #1: Changing 'neutral' to null
# Card 304, Art #1, Cost #2: Changing 'neutral' to null
# Card 305, Art #1, Cost #1: Changing 'neutral' to null
# Card 306, Art #1, Cost #2: Changing 'neutral' to null
# Card 307, Art #1, Cost #3: Changing 'neutral' to null
# Card 308, Art #1, Cost #2: Changing 'neutral' to null
# Card 308, Art #1, Cost #3: Changing 'neutral' to null
# Card 309, Art #1, Cost #1: Changing 'neutral' to null
# Card 311, Art #1, Cost #1: Changing 'neutral' to null
# Card 311, Art #2, Cost #2: Changing 'neutral' to null
# Card 312, Art #1, Cost #1: Changing 'neutral' to null
# Card 314, Art #1, Cost #3: Changing 'neutral' to null
# Card 315, Art #1, Cost #1: Changing 'neutral' to null
# Card 316, Art #1, Cost #1: Changing 'neutral' to null
# Card 317, Art #1, Cost #1: Changing 'neutral' to null
# Card 317, Art #2, Cost #2: Changing 'neutral' to null
# Card 318, Art #1, Cost #1: Changing 'neutral' to null
# Card 319, Art #1, Cost #1: Changing 'neutral' to null
# Card 319, Art #1, Cost #2: Changing 'neutral' to null
# Card 320, Art #1, Cost #2: Changing 'neutral' to null
# Card 320, Art #1, Cost #3: Changing 'neutral' to null
# Card 321, Art #1, Cost #1: Changing 'neutral' to null
# Card 324, Art #1, Cost #2: Changing 'neutral' to null
# Card 325, Art #1, Cost #2: Changing 'neutral' to null
# Card 326, Art #1, Cost #3: Changing 'neutral' to null
# Card 327, Art #1, Cost #2: Changing 'neutral' to null
# Card 327, Art #1, Cost #3: Changing 'neutral' to null
# Card 328, Art #1, Cost #1: Changing 'neutral' to null
# Card 330, Art #1, Cost #1: Changing 'neutral' to null
# Card 331, Art #1, Cost #2: Changing 'neutral' to null
# Card 332, Art #1, Cost #1: Changing 'neutral' to null
# Card 333, Art #1, Cost #1: Changing 'neutral' to null
# Card 333, Art #2, Cost #2: Changing 'neutral' to null
# Card 334, Art #1, Cost #1: Changing 'neutral' to null
# Card 335, Art #1, Cost #2: Changing 'neutral' to null
# Card 335, Art #1, Cost #3: Changing 'neutral' to null
# Card 336, Art #1, Cost #1: Changing 'neutral' to null
# Card 337, Art #1, Cost #1: Changing 'neutral' to null
# Card 338, Art #1, Cost #1: Changing 'neutral' to null
# Card 339, Art #1, Cost #1: Changing 'neutral' to null
# Card 340, Art #1, Cost #1: Changing 'neutral' to null
# Card 341, Art #1, Cost #1: Changing 'neutral' to null
# Card 3, Art #1, Cost #1: Changing 'neutral' to null
# Card 4, Art #1, Cost #1: Changing 'neutral' to null
# Card 5, Art #2, Cost #2: Changing 'neutral' to null
# Card 6, Art #1, Cost #2: Changing 'neutral' to null
# Card 6, Art #2, Cost #3: Changing 'neutral' to null
# Card 8, Art #1, Cost #1: Changing 'neutral' to null
# Card 9, Art #1, Cost #1: Changing 'neutral' to null
# Card 10, Art #1, Cost #2: Changing 'neutral' to null
# Card 11, Art #2, Cost #3: Changing 'neutral' to null
# Card 13, Art #1, Cost #1: Changing 'neutral' to null
# Card 13, Art #1, Cost #2: Changing 'neutral' to null
# Card 15, Art #1, Cost #1: Changing 'neutral' to null
# Card 41, Art #1, Cost #1: Changing 'neutral' to null
# Card 43, Art #1, Cost #1: Changing 'neutral' to null
# Card 44, Art #1, Cost #2: Changing 'neutral' to null
# Card 48, Art #1, Cost #1: Changing 'neutral' to null
# Card 49, Art #2, Cost #2: Changing 'neutral' to null
# Card 51, Art #1, Cost #1: Changing 'neutral' to null
# Card 52, Art #1, Cost #2: Changing 'neutral' to null
# Card 52, Art #1, Cost #3: Changing 'neutral' to null
# Card 54, Art #1, Cost #1: Changing 'neutral' to null
# Card 55, Art #1, Cost #3: Changing 'neutral' to null
# Card 57, Art #1, Cost #1: Changing 'neutral' to null
# Card 58, Art #2, Cost #2: Changing 'neutral' to null
# Card 59, Art #1, Cost #1: Changing 'neutral' to null
# Card 60, Art #1, Cost #2: Changing 'neutral' to null
# Card 60, Art #1, Cost #3: Changing 'neutral' to null
# Card 62, Art #1, Cost #1: Changing 'neutral' to null
# Card 63, Art #1, Cost #2: Changing 'neutral' to null
# Card 64, Art #1, Cost #1: Changing 'neutral' to null
# Card 65, Art #1, Cost #2: Changing 'neutral' to null
# Card 65, Art #1, Cost #3: Changing 'neutral' to null
# Card 66, Art #1, Cost #1: Changing 'neutral' to null
# Card 68, Art #2, Cost #2: Changing 'neutral' to null
# Card 70, Art #1, Cost #1: Changing 'neutral' to null
# Card 73, Art #1, Cost #1: Changing 'neutral' to null
# Card 74, Art #1, Cost #2: Changing 'neutral' to null
# Card 75, Art #1, Cost #1: Changing 'neutral' to null
# Card 77, Art #1, Cost #4: Changing 'neutral' to null
# Card 79, Art #1, Cost #1: Changing 'neutral' to null
# Card 81, Art #1, Cost #1: Changing 'neutral' to null
# Card 82, Art #1, Cost #4: Changing 'neutral' to null
# Card 84, Art #1, Cost #1: Changing 'neutral' to null
# Card 85, Art #2, Cost #2: Changing 'neutral' to null
# Card 86, Art #1, Cost #2: Changing 'neutral' to null
# Card 87, Art #1, Cost #2: Changing 'neutral' to null
# Card 87, Art #2, Cost #2: Changing 'neutral' to null
# Card 87, Art #2, Cost #3: Changing 'neutral' to null
# Card 89, Art #1, Cost #1: Changing 'neutral' to null
# Card 90, Art #1, Cost #1: Changing 'neutral' to null
# Card 90, Art #1, Cost #2: Changing 'neutral' to null
# Card 91, Art #1, Cost #1: Changing 'neutral' to null
# Card 92, Art #1, Cost #2: Changing 'neutral' to null
# Card 92, Art #1, Cost #3: Changing 'neutral' to null
# Card 93, Art #1, Cost #1: Changing 'neutral' to null
# Card 95, Art #2, Cost #2: Changing 'neutral' to null
# Card 97, Art #1, Cost #1: Changing 'neutral' to null
# Card 98, Art #1, Cost #3: Changing 'neutral' to null
# Card 99, Art #1, Cost #1: Changing 'neutral' to null
# Card 102, Art #1, Cost #1: Changing 'neutral' to null
# Card 106, Art #1, Cost #1: Changing 'neutral' to null
# Card 107, Art #2, Cost #2: Changing 'neutral' to null
# Card 108, Art #1, Cost #2: Changing 'neutral' to null
# Card 109, Art #1, Cost #2: Changing 'neutral' to null
# Card 111, Art #1, Cost #1: Changing 'neutral' to null
# Card 112, Art #1, Cost #2: Changing 'neutral' to null
# Card 113, Art #1, Cost #1: Changing 'neutral' to null
# Card 114, Art #1, Cost #2: Changing 'neutral' to null
# Card 115, Art #1, Cost #1: Changing 'neutral' to null
# Card 117, Art #2, Cost #2: Changing 'neutral' to null
# Card 118, Art #1, Cost #1: Changing 'neutral' to null
# Card 118, Art #1, Cost #2: Changing 'neutral' to null
# Card 120, Art #1, Cost #4: Changing 'neutral' to null
# Card 123, Art #1, Cost #1: Changing 'neutral' to null
# Card 124, Art #1, Cost #2: Changing 'neutral' to null
# Card 125, Art #2, Cost #2: Changing 'neutral' to null
# Card 126, Art #1, Cost #1: Changing 'neutral' to null
# Card 127, Art #1, Cost #2: Changing 'neutral' to null
# Card 127, Art #2, Cost #3: Changing 'neutral' to null
# Card 129, Art #1, Cost #2: Changing 'neutral' to null
# Card 130, Art #1, Cost #1: Changing 'neutral' to null
# Card 131, Art #1, Cost #1: Changing 'neutral' to null
# Card 131, Art #1, Cost #2: Changing 'neutral' to null
# Card 131, Art #2, Cost #2: Changing 'neutral' to null
# Card 131, Art #2, Cost #3: Changing 'neutral' to null
# Card 134, Art #1, Cost #1: Changing 'neutral' to null
# Card 134, Art #2, Cost #2: Changing 'neutral' to null
# Card 135, Art #1, Cost #1: Changing 'neutral' to null
# Card 136, Art #1, Cost #2: Changing 'neutral' to null
# Card 136, Art #1, Cost #3: Changing 'neutral' to null
# Card 137, Art #1, Cost #1: Changing 'neutral' to null
# Card 138, Art #1, Cost #1: Changing 'neutral' to null
# Card 139, Art #1, Cost #1: Changing 'neutral' to null
# Card 139, Art #1, Cost #2: Changing 'neutral' to null
# Card 140, Art #1, Cost #1: Changing 'neutral' to null
# Card 141, Art #1, Cost #1: Changing 'neutral' to null
# Card 142, Art #1, Cost #1: Changing 'neutral' to null
# Card 142, Art #1, Cost #2: Changing 'neutral' to null
# Card 691, Art #2, Cost #2: Changing 'neutral' to null
# Card 692, Art #1, Cost #2: Changing 'neutral' to null
# Card 694, Art #1, Cost #3: Changing 'neutral' to null
# Card 695, Art #1, Cost #3: Changing 'neutral' to null
# Card 696, Art #1, Cost #2: Changing 'neutral' to null
# Card 696, Art #1, Cost #3: Changing 'neutral' to null
# Card 697, Art #1, Cost #2: Changing 'neutral' to null
# Card 697, Art #1, Cost #3: Changing 'neutral' to null
# Card 699, Art #2, Cost #2: Changing 'neutral' to null
# Card 700, Art #1, Cost #1: Changing 'neutral' to null
# Card 701, Art #1, Cost #2: Changing 'neutral' to null
# Card 702, Art #1, Cost #2: Changing 'neutral' to null
# Card 702, Art #1, Cost #3: Changing 'neutral' to null
# Card 703, Art #1, Cost #2: Changing 'neutral' to null
# Card 703, Art #1, Cost #3: Changing 'neutral' to null
# Card 705, Art #1, Cost #2: Changing 'neutral' to null
# Card 705, Art #1, Cost #3: Changing 'neutral' to null
# Card 706, Art #1, Cost #2: Changing 'neutral' to null
# Card 706, Art #1, Cost #3: Changing 'neutral' to null
# Card 706, Art #1, Cost #4: Changing 'neutral' to null
# Card 707, Art #1, Cost #2: Changing 'neutral' to null
# Card 707, Art #1, Cost #3: Changing 'neutral' to null
# Card 707, Art #1, Cost #4: Changing 'neutral' to null
# Card 708, Art #1, Cost #2: Changing 'neutral' to null
# Card 709, Art #1, Cost #1: Changing 'neutral' to null
# Card 709, Art #2, Cost #2: Changing 'neutral' to null
# Card 710, Art #1, Cost #1: Changing 'neutral' to null
# Card 710, Art #2, Cost #2: Changing 'neutral' to null
# Card 711, Art #1, Cost #2: Changing 'neutral' to null
# Card 712, Art #1, Cost #2: Changing 'neutral' to null
# Card 712, Art #1, Cost #3: Changing 'neutral' to null
# Card 713, Art #1, Cost #2: Changing 'neutral' to null
# Card 713, Art #1, Cost #3: Changing 'neutral' to null
# Card 714, Art #1, Cost #2: Changing 'neutral' to null
# Card 715, Art #1, Cost #1: Changing 'neutral' to null
# Card 716, Art #1, Cost #2: Changing 'neutral' to null
# Card 717, Art #1, Cost #2: Changing 'neutral' to null
# Card 718, Art #1, Cost #2: Changing 'neutral' to null
# Card 719, Art #1, Cost #2: Changing 'neutral' to null
# Card 720, Art #1, Cost #1: Changing 'neutral' to null
# Card 722, Art #1, Cost #1: Changing 'neutral' to null
# Card 722, Art #2, Cost #2: Changing 'neutral' to null
# Card 723, Art #1, Cost #1: Changing 'neutral' to null
# Card 723, Art #1, Cost #2: Changing 'neutral' to null
# Card 724, Art #2, Cost #3: Changing 'neutral' to null
# Card 725, Art #2, Cost #3: Changing 'neutral' to null
# Card 726, Art #1, Cost #2: Changing 'neutral' to null
# Card 727, Art #1, Cost #2: Changing 'neutral' to null
# Card 728, Art #1, Cost #2: Changing 'neutral' to null
# Card 729, Art #1, Cost #1: Changing 'neutral' to null
# Card 729, Art #2, Cost #1: Changing 'neutral' to null
# Card 729, Art #2, Cost #2: Changing 'neutral' to null
# Card 730, Art #1, Cost #2: Changing 'neutral' to null
# Card 730, Art #1, Cost #3: Changing 'neutral' to null
# Card 731, Art #1, Cost #1: Changing 'neutral' to null
# Card 731, Art #1, Cost #2: Changing 'neutral' to null
# Card 733, Art #1, Cost #1: Changing 'neutral' to null
# Card 733, Art #2, Cost #2: Changing 'neutral' to null
# Card 734, Art #1, Cost #1: Changing 'neutral' to null
# Card 735, Art #2, Cost #2: Changing 'neutral' to null
# Card 736, Art #2, Cost #3: Changing 'neutral' to null
# Card 737, Art #2, Cost #3: Changing 'neutral' to null
# Card 738, Art #1, Cost #1: Changing 'neutral' to null
# Card 738, Art #2, Cost #2: Changing 'neutral' to null
# Card 739, Art #1, Cost #1: Changing 'neutral' to null
# Card 740, Art #1, Cost #1: Changing 'neutral' to null
# Card 743, Art #1, Cost #2: Changing 'neutral' to null
# Card 743, Art #2, Cost #1: Changing 'neutral' to null
# Card 743, Art #2, Cost #2: Changing 'neutral' to null
# Card 743, Art #2, Cost #3: Changing 'neutral' to null
# Card 744, Art #1, Cost #1: Changing 'neutral' to null
# Card 744, Art #1, Cost #2: Changing 'neutral' to null
# Card 745, Art #1, Cost #3: Changing 'neutral' to null
# Card 746, Art #1, Cost #3: Changing 'neutral' to null
# Card 748, Art #2, Cost #1: Changing 'neutral' to null
# Card 748, Art #2, Cost #2: Changing 'neutral' to null
# Card 748, Art #2, Cost #3: Changing 'neutral' to null
# Card 749, Art #1, Cost #1: Changing 'neutral' to null
# Card 749, Art #1, Cost #2: Changing 'neutral' to null
# Card 750, Art #1, Cost #2: Changing 'neutral' to null
# Card 751, Art #1, Cost #2: Changing 'neutral' to null
# Card 751, Art #1, Cost #3: Changing 'neutral' to null
# Card 752, Art #1, Cost #2: Changing 'neutral' to null
# Card 752, Art #1, Cost #3: Changing 'neutral' to null
# Card 753, Art #1, Cost #1: Changing 'neutral' to null
# Card 754, Art #1, Cost #1: Changing 'neutral' to null
# Card 754, Art #2, Cost #2: Changing 'neutral' to null
# Card 754, Art #2, Cost #3: Changing 'neutral' to null
# Card 755, Art #1, Cost #1: Changing 'neutral' to null
# Card 756, Art #1, Cost #2: Changing 'neutral' to null
# Card 757, Art #1, Cost #2: Changing 'neutral' to null
# Card 757, Art #1, Cost #3: Changing 'neutral' to null
# Card 758, Art #1, Cost #2: Changing 'neutral' to null
# Card 758, Art #1, Cost #3: Changing 'neutral' to null
# Card 759, Art #1, Cost #2: Changing 'neutral' to null
# Card 760, Art #1, Cost #2: Changing 'neutral' to null
# Card 761, Art #1, Cost #1: Changing 'neutral' to null
# Card 762, Art #1, Cost #2: Changing 'neutral' to null
# Card 762, Art #1, Cost #3: Changing 'neutral' to null
# Card 763, Art #1, Cost #2: Changing 'neutral' to null
# Card 763, Art #1, Cost #3: Changing 'neutral' to null
# Card 763, Art #1, Cost #4: Changing 'neutral' to null
# Card 764, Art #1, Cost #3: Changing 'neutral' to null
# Card 765, Art #1, Cost #2: Changing 'neutral' to null
# Card 765, Art #1, Cost #3: Changing 'neutral' to null
# Card 766, Art #1, Cost #2: Changing 'neutral' to null
# Card 766, Art #1, Cost #3: Changing 'neutral' to null
# Card 380, Art #2, Cost #2: Changing 'neutral' to null
# Card 381, Art #1, Cost #1: Changing 'neutral' to null
# Card 382, Art #1, Cost #2: Changing 'neutral' to null
# Card 383, Art #1, Cost #3: Changing 'neutral' to null
# Card 384, Art #1, Cost #3: Changing 'neutral' to null
# Card 385, Art #1, Cost #1: Changing 'neutral' to null
# Card 385, Art #2, Cost #2: Changing 'neutral' to null
# Card 386, Art #1, Cost #1: Changing 'neutral' to null
# Card 386, Art #1, Cost #2: Changing 'neutral' to null
# Card 387, Art #1, Cost #1: Changing 'neutral' to null
# Card 387, Art #1, Cost #2: Changing 'neutral' to null
# Card 387, Art #2, Cost #2: Changing 'neutral' to null
# Card 387, Art #2, Cost #3: Changing 'neutral' to null
# Card 388, Art #1, Cost #1: Changing 'neutral' to null
# Card 388, Art #1, Cost #2: Changing 'neutral' to null
# Card 388, Art #2, Cost #2: Changing 'neutral' to null
# Card 388, Art #2, Cost #3: Changing 'neutral' to null
# Card 389, Art #1, Cost #1: Changing 'neutral' to null
# Card 390, Art #1, Cost #2: Changing 'neutral' to null
# Card 391, Art #1, Cost #1: Changing 'neutral' to null
# Card 392, Art #1, Cost #2: Changing 'neutral' to null
# Card 393, Art #1, Cost #2: Changing 'neutral' to null
# Card 393, Art #1, Cost #3: Changing 'neutral' to null
# Card 393, Art #1, Cost #4: Changing 'neutral' to null
# Card 394, Art #1, Cost #2: Changing 'neutral' to null
# Card 394, Art #1, Cost #3: Changing 'neutral' to null
# Card 394, Art #1, Cost #4: Changing 'neutral' to null
# Card 395, Art #1, Cost #1: Changing 'neutral' to null
# Card 395, Art #2, Cost #2: Changing 'neutral' to null
# Card 396, Art #1, Cost #1: Changing 'neutral' to null
# Card 397, Art #1, Cost #2: Changing 'neutral' to null
# Card 398, Art #1, Cost #2: Changing 'neutral' to null
# Card 399, Art #2, Cost #2: Changing 'neutral' to null
# Card 400, Art #1, Cost #1: Changing 'neutral' to null
# Card 401, Art #1, Cost #1: Changing 'neutral' to null
# Card 401, Art #1, Cost #2: Changing 'neutral' to null
# Card 402, Art #1, Cost #2: Changing 'neutral' to null
# Card 402, Art #1, Cost #3: Changing 'neutral' to null
# Card 403, Art #1, Cost #2: Changing 'neutral' to null
# Card 403, Art #1, Cost #3: Changing 'neutral' to null
# Card 404, Art #1, Cost #2: Changing 'neutral' to null
# Card 404, Art #2, Cost #2: Changing 'neutral' to null
# Card 404, Art #2, Cost #3: Changing 'neutral' to null
# Card 405, Art #1, Cost #2: Changing 'neutral' to null
# Card 405, Art #2, Cost #2: Changing 'neutral' to null
# Card 405, Art #2, Cost #3: Changing 'neutral' to null
# Card 406, Art #1, Cost #1: Changing 'neutral' to null
# Card 407, Art #1, Cost #2: Changing 'neutral' to null
# Card 408, Art #1, Cost #1: Changing 'neutral' to null
# Card 409, Art #1, Cost #2: Changing 'neutral' to null
# Card 410, Art #1, Cost #3: Changing 'neutral' to null
# Card 411, Art #1, Cost #3: Changing 'neutral' to null
# Card 412, Art #1, Cost #2: Changing 'neutral' to null
# Card 412, Art #1, Cost #3: Changing 'neutral' to null
# Card 413, Art #1, Cost #2: Changing 'neutral' to null
# Card 413, Art #1, Cost #3: Changing 'neutral' to null
# Card 414, Art #1, Cost #1: Changing 'neutral' to null
# Card 414, Art #2, Cost #2: Changing 'neutral' to null
# Card 415, Art #1, Cost #1: Changing 'neutral' to null
# Card 417, Art #1, Cost #3: Changing 'neutral' to null
# Card 418, Art #1, Cost #3: Changing 'neutral' to null
# Card 419, Art #1, Cost #1: Changing 'neutral' to null
# Card 420, Art #1, Cost #1: Changing 'neutral' to null
# Card 420, Art #2, Cost #2: Changing 'neutral' to null
# Card 421, Art #1, Cost #1: Changing 'neutral' to null
# Card 422, Art #1, Cost #1: Changing 'neutral' to null
# Card 422, Art #1, Cost #2: Changing 'neutral' to null
# Card 423, Art #1, Cost #2: Changing 'neutral' to null
# Card 423, Art #1, Cost #3: Changing 'neutral' to null
# Card 424, Art #1, Cost #2: Changing 'neutral' to null
# Card 424, Art #1, Cost #3: Changing 'neutral' to null
# Card 427, Art #1, Cost #2: Changing 'neutral' to null
# Card 428, Art #1, Cost #2: Changing 'neutral' to null
# Card 429, Art #1, Cost #3: Changing 'neutral' to null
# Card 430, Art #1, Cost #3: Changing 'neutral' to null
# Card 431, Art #1, Cost #2: Changing 'neutral' to null
# Card 431, Art #1, Cost #3: Changing 'neutral' to null
# Card 433, Art #1, Cost #1: Changing 'neutral' to null
# Card 434, Art #1, Cost #2: Changing 'neutral' to null
# Card 435, Art #1, Cost #2: Changing 'neutral' to null
# Card 436, Art #1, Cost #1: Changing 'neutral' to null
# Card 436, Art #2, Cost #2: Changing 'neutral' to null
# Card 437, Art #1, Cost #1: Changing 'neutral' to null
# Card 438, Art #1, Cost #2: Changing 'neutral' to null
# Card 438, Art #1, Cost #3: Changing 'neutral' to null
# Card 439, Art #1, Cost #1: Changing 'neutral' to null
# Card 440, Art #1, Cost #1: Changing 'neutral' to null
# Card 441, Art #1, Cost #1: Changing 'neutral' to null
# Card 442, Art #1, Cost #1: Changing 'neutral' to null
# Card 443, Art #1, Cost #1: Changing 'neutral' to null
# Card 444, Art #1, Cost #1: Changing 'neutral' to null
# Card 445, Art #2, Cost #3: Changing 'neutral' to null
# Card 446, Art #1, Cost #2: Changing 'neutral' to null
# Card 446, Art #2, Cost #3: Changing 'neutral' to null
# Card 446, Art #2, Cost #4: Changing 'neutral' to null
# Card 447, Art #1, Cost #2: Changing 'neutral' to null
# Card 447, Art #2, Cost #3: Changing 'neutral' to null
# Card 203, Art #1, Cost #1: Changing 'neutral' to null
# Card 204, Art #1, Cost #1: Changing 'neutral' to null
# Card 487, Art #1, Cost #2: Changing 'neutral' to null
# Card 487, Art #1, Cost #3: Changing 'neutral' to null
# Card 205, Art #1, Cost #1: Changing 'neutral' to null
# Card 177, Art #1, Cost #1: Changing 'neutral' to null
# Card 206, Art #1, Cost #1: Changing 'neutral' to null
# Card 509, Art #1, Cost #1: Changing 'neutral' to null
# Card 207, Art #1, Cost #1: Changing 'neutral' to null
# Card 488, Art #1, Cost #2: Changing 'neutral' to null
# Card 488, Art #1, Cost #3: Changing 'neutral' to null
# Card 178, Art #1, Cost #1: Changing 'neutral' to null
# Card 208, Art #1, Cost #1: Changing 'neutral' to null
# Card 209, Art #1, Cost #1: Changing 'neutral' to null
# Card 190, Art #1, Cost #1: Changing 'neutral' to null
# Card 210, Art #1, Cost #1: Changing 'neutral' to null
# Card 179, Art #1, Cost #1: Changing 'neutral' to null
# Card 211, Art #1, Cost #2: Changing 'neutral' to null
# Card 510, Art #1, Cost #1: Changing 'neutral' to null
# Card 212, Art #1, Cost #1: Changing 'neutral' to null
# Card 490, Art #1, Cost #2: Changing 'neutral' to null
# Card 490, Art #1, Cost #3: Changing 'neutral' to null
# Card 192, Art #1, Cost #1: Changing 'neutral' to null
# Card 213, Art #1, Cost #1: Changing 'neutral' to null
# Card 491, Art #1, Cost #3: Changing 'neutral' to null
# Card 193, Art #1, Cost #1: Changing 'neutral' to null
# Card 214, Art #1, Cost #1: Changing 'neutral' to null
# Card 180, Art #1, Cost #1: Changing 'neutral' to null
# Card 215, Art #1, Cost #2: Changing 'neutral' to null
# Card 181, Art #1, Cost #1: Changing 'neutral' to null
# Card 216, Art #1, Cost #1: Changing 'neutral' to null
# Card 492, Art #1, Cost #2: Changing 'neutral' to null
# Card 182, Art #1, Cost #1: Changing 'neutral' to null
# Card 198, Art #1, Cost #1: Changing 'neutral' to null
# Card 217, Art #1, Cost #1: Changing 'neutral' to null
# Card 217, Art #1, Cost #2: Changing 'neutral' to null
# Card 218, Art #1, Cost #1: Changing 'neutral' to null
# Card 493, Art #1, Cost #2: Changing 'neutral' to null
# Card 493, Art #2, Cost #3: Changing 'neutral' to null
# Card 219, Art #1, Cost #1: Changing 'neutral' to null
# Card 220, Art #1, Cost #1: Changing 'neutral' to null
# Card 494, Art #1, Cost #2: Changing 'neutral' to null
# Card 494, Art #1, Cost #3: Changing 'neutral' to null
# Card 483, Art #1, Cost #1: Changing 'neutral' to null
# Card 500, Art #1, Cost #1: Changing 'neutral' to null
# Card 511, Art #1, Cost #1: Changing 'neutral' to null
# Card 512, Art #1, Cost #1: Changing 'neutral' to null
# Card 501, Art #1, Cost #1: Changing 'neutral' to null
# Card 201, Art #1, Cost #1: Changing 'neutral' to null
# Card 502, Art #1, Cost #1: Changing 'neutral' to null
# Card 507, Art #1, Cost #2: Changing 'neutral' to null
# Card 513, Art #1, Cost #1: Changing 'neutral' to null
# Card 514, Art #1, Cost #1: Changing 'neutral' to null
# Card 485, Art #1, Cost #3: Changing 'neutral' to null
# Card 503, Art #1, Cost #1: Changing 'neutral' to null
# Card 504, Art #1, Cost #1: Changing 'neutral' to null
# Card 515, Art #1, Cost #1: Changing 'neutral' to null
# Card 812, Art #1, Cost #1: Changing 'neutral' to null
# Card 836, Art #1, Cost #3: Changing 'neutral' to null
# Card 804, Art #1, Cost #2: Changing 'neutral' to null
# Card 813, Art #1, Cost #1: Changing 'neutral' to null
# Card 814, Art #1, Cost #1: Changing 'neutral' to null
# Card 815, Art #1, Cost #1: Changing 'neutral' to null
# Card 816, Art #1, Cost #1: Changing 'neutral' to null
# Card 816, Art #2, Cost #1: Changing 'neutral' to null
# Card 816, Art #2, Cost #2: Changing 'neutral' to null
# Card 816, Art #2, Cost #3: Changing 'neutral' to null
# Card 197, Art #1, Cost #1: Changing 'neutral' to null
# Card 186, Art #1, Cost #1: Changing 'neutral' to null
# Card 495, Art #1, Cost #2: Changing 'neutral' to null
# Card 495, Art #2, Cost #3: Changing 'neutral' to null
# Card 187, Art #1, Cost #1: Changing 'neutral' to null
# Card 496, Art #2, Cost #3: Changing 'neutral' to null
# Card 833, Art #1, Cost #1: Changing 'neutral' to null
# Card 833, Art #1, Cost #2: Changing 'neutral' to null
# Card 497, Art #1, Cost #1: Changing 'neutral' to null
# Card 811, Art #1, Cost #1: Changing 'neutral' to null
# Card 818, Art #1, Cost #1: Changing 'neutral' to null
# Card 498, Art #1, Cost #1: Changing 'neutral' to null
# Card 819, Art #1, Cost #1: Changing 'neutral' to null
# Card 499, Art #1, Cost #1: Changing 'neutral' to null
# Card 499, Art #1, Cost #2: Changing 'neutral' to null
# Card 56, Art #1, Cost #3: Changing 'neutral' to null
# Card 61, Art #1, Cost #2: Changing 'neutral' to null
# Card 61, Art #1, Cost #3: Changing 'neutral' to null
# Card 78, Art #1, Cost #4: Changing 'neutral' to null
# Card 83, Art #1, Cost #4: Changing 'neutral' to null
# Card 88, Art #1, Cost #2: Changing 'neutral' to null
# Card 88, Art #2, Cost #2: Changing 'neutral' to null
# Card 88, Art #2, Cost #3: Changing 'neutral' to null
# Card 110, Art #1, Cost #2: Changing 'neutral' to null
# Card 121, Art #1, Cost #4: Changing 'neutral' to null
# Card 132, Art #1, Cost #1: Changing 'neutral' to null
# Card 132, Art #1, Cost #2: Changing 'neutral' to null
# Card 132, Art #2, Cost #2: Changing 'neutral' to null
# Card 132, Art #2, Cost #3: Changing 'neutral' to null
#
# Replaced 659 instances of 'neutral' with null in 472 cards
# Saved updated data to /Users/chingli/lichingchester/projects/hololive-ocg-wiki/data-grab-scripts/data_transform/../../data/cards_i18n.json
#
# Verification results:
# - Remaining 'neutral' values: 0
# - Null values found: 659
#
# Script completed!
